# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
expr = x**2-5*x+4
expr.diff(x,1)
# Out:
# 2*x - 5

# %%
from sympy import solveset, Eq
y = expr.diff(x,1)
solveset(Eq(y, 0), x)
# Out:
# {5/2}

# %% [markdown]
# Задание 1.4
#
# 1 point possible (graded)
#
# Найдите область убывания функции :

# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
expr = x**3-6*x**2+2
expr.diff(x,1)
# Out:
# 3*x**2 - 12*x

# %%
from sympy import solveset, Eq
y = expr.diff(x,1)
solveset(Eq(y, 0), x)
# Out:
# {0, 4}

# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
y = sympy.Symbol("y")
expr = x**3-6*x**2+2
expr.diff(x,1)
# Out:
# 3*x**2 - 12*x

# %%
from sympy import symbols, cos, diff

a, b, c = symbols('a b c', real=True)
f = 5*a*b - a*cos(c) + a**8 + c**2*b

print(diff(f, a))
# Out:
# 8*a**7 + 5*b - cos(c)

# %% [markdown]
# Задание 2.3
#
# 4 points possible (graded)
#
# 1. Чему равны частные производные ?

# %%
from sympy import symbols, cos, diff

x,y = symbols('x y', real=True)
f = x**2-y**2

print(diff(f, x))
print(diff(f, y))
# Out:
# 2*x
# -2*y

# %% [markdown]
# Задание 2.4
#
# 2 points possible (graded)

# %%
from sympy import symbols, cos, diff

a,b = symbols('a b', real=True)
f = (5-a-2*b)**2

print(diff(f, a))
print(diff(f, b))
print(diff(f, a, b))
# Out:
# 2*a + 4*b - 10
# 4*a + 8*b - 20
# 4

# %% [markdown]
# Задание 2.5
#
# 2 points possible (graded)
#
# Вычислите частные производные для функции  в точке .

# %%
from sympy import symbols, cos, diff

x,y = symbols('x y', real=True)
f = x**2+3*x*y+4*y**2

print(diff(f, x),2)
print(diff(f, y))
print(diff(f, x, y))
# Out:
# 2*x + 3*y 2
# 3*x + 8*y
# 3

# %% [markdown]
# Задание 2.6
#
# 1 point possible (graded)
#
# Найдите частные производные для функции . Отметьте производную по :

# %%
from sympy import symbols, cos, sin, diff

x,y = symbols('x y', real=True)
f = y*sin(x)+sin(y)

print(diff(f, x))
print(diff(f, y))
# Out:
# y*cos(x)
# sin(x) + cos(y)

# %%
import sympy
from sympy import diff
x = sympy.Symbol("x")
expr = x**2-5*x+4
expr.diff(x,1)
# Out:
# 2*x - 5

# %%
from sympy import symbols, cos, diff,exp

x,y = symbols('x y', real=True)
f = exp(x)+5*x*(y**3)

print(diff(f, x,2))
print(diff(f, y,2))
print(diff(f, x, y))
# Out:
# exp(x)
# 30*x*y
# 15*y**2

# %%
from sympy import symbols, cos, diff,exp

x,y = symbols('x y', real=True)
f = -x**2+6*x-2*y**2+4*y

print(diff(f, x))
print(diff(f, y))


print(diff(f, x,2))
print(diff(f, y,2))
print(diff(f, x, y))
# Out:
# 6 - 2*x
# 4 - 4*y
# -2
# -4
# 0

# %%
from sympy import *
 
x, y = symbols('x, y')
f=x**3+3*x*y**2-15*x-12*y+1
eq1 = Eq(3*x**2+3*y**2-15,0)
eq2 = Eq(6*x*y-12, 0)
 
sol = solve([eq1, eq2], [x, y])
print(sol)

print(diff(f, x))
print(diff(f, y))


print(diff(f, x,2))
print(diff(f, y,2))
print(diff(f, x, y))
# Out:
# [(-2, -1), (-1, -2), (1, 2), (2, 1)]
# 3*x**2 + 3*y**2 - 15
# 6*x*y - 12
# 6*x
# 6*x
# 6*y

# %% [markdown]
# Задание 3.4
# 2 points possible (graded)
# Найдите экстремумы функции .

# %%
from sympy import symbols, cos, diff,exp

x,y = symbols('x y', real=True)
f = 4*x**2-6*x*y-34*x+5*y**2+42*y+7

print(diff(f, x))
print(diff(f, y))


print(diff(f, x,2))
print(diff(f, y,2))
print(diff(f, x, y))
# Out:
# 8*x - 6*y - 34
# -6*x + 10*y + 42
# 8
# 10
# -6

# %% [markdown]
# Задание 3.5
#
# 1 point possible (graded)
#
# Вычислите матрицу Гессе для функции  в точке  и найдите её определитель:

# %%
from sympy import symbols, cos, diff,exp

x,y = symbols('x y', real=True)
f = x**3-2*x*y-y**6

print(diff(f, x))
print(diff(f, y))


print(diff(f, x,2))
print(diff(f, y,2))
print(diff(f, x, y))
# Out:
# 3*x**2 - 2*y
# -2*x - 6*y**5
# 6*x
# -30*y**4
# -2

# %% [markdown]
# Задание 3.9
# 4 points possible (graded)
# Найдите экстремумы функции .

# %%
from sympy import symbols, cos, diff,exp

x,y = symbols('x y', real=True)
f = x**3+y**3-3*x*y

print(diff(f, x))
print(diff(f, y))

print(diff(f, x,2))
print(diff(f, y,2))
print(diff(f, x, y))
# Out:
# 3*x**2 - 3*y
# -3*x + 3*y**2
# 6*x
# 6*y
# -3

# %%
import numpy as np
 
def func_rosen(x):
    r = np.sum(100*(x[1:]-x[:-1]**2)**2 + (1-x[:-1])**2, axis=0)
    return r

# %%
import matplotlib.pyplot as plt
graph = plt.figure(figsize=[25, 15])
ax = graph.add_subplot(projection='3d')
ax.view_init(45, 30)
x1 = np.arange(-3, 3, 0.2)
x2 = np.arange(-2, 4, 0.2)
x1, x2 = np.meshgrid(x1, x2)
y = func_rosen(np.array([x1,x2]))
surf = ax.plot_surface(x1, x2, y)
plt.show()

# %%
from scipy.optimize import minimize
x1 = np.array([2.4, 1.5, 2.1, 0.7, 1.1])
result_point = minimize(func_rosen, x1, method='powell')
print(result_point.x)
# Out:
# [1. 1. 1. 1. 1.]

# %%
from scipy.optimize import minimize
x1 = np.array([2.4, 1.5, 2.1, 0.7, 1.1])
result_point = minimize(func_rosen, x1, method='nelder-mead')
print(result_point.x)
# Out:
# [1.02760651 1.05589639 1.11509457 1.2440091  1.54862169]

# %% [markdown]
# Задание 4.5
#
# 5 points possible (graded)
#
# Оптимизируйте функцию Розенброка с помощью уже известного вам метода наименьших квадратов с использованием той же точки, которая фигурировала в наших решениях до этого.
#
# Для реализации этого алгоритма используется функция least_squares.
#
# → Мы используем этот метод, так как он хорошо подходит для задач безусловной оптимизации и считается методом первого выбора, если необходимо оптимизировать функцию, для которой нет ограничений.
#
# В качестве ответа внесите в поля ниже координаты найденной точки в порядке их следования в коде (одно поле — одна координата). Ответ округлите до трёх знаков после точки-разделителя.

# %%
from scipy.optimize import least_squares
x1 = np.array([2.4, 1.5, 2.1, 0.7, 1.1])
result_point = least_squares(func_rosen, x1)
print(np.around((result_point.x), 3))
# Out:
# [0.939 0.882 0.776 0.603 0.361]

# %%
from sympy import *
a,b,w=symbols(' a b w' )
g = 3*a**2 + a + 4*b + 5*b**2
print('Целевая функция для аргументов a и b :\n f = ', g)
q = a + b - 200
print('Функция ограничений: ', q,'= 0')
f = 3*a**2 + a + 4*b + 5*b**2 + w*(a + b - 200)
print('Функция Лагранжа :\n ',f)
fa = f.diff(a)
print('df/da =',fa,'= 0')
fb = f.diff(b)
print('df/db =',fb,'= 0')
fw = f.diff(w)
print('df/dw =',fw,'= 0')
sols = solve([fa,fb,fw],a,b,w)
print('Стационарная точка M(x,y):\n',float(sols[a]),',',float(sols[b]))

#Целевая функция для аргументов a и b :
#f =  3*a**2 + a + 5*b**2 + 4*b
#Функция ограничений:  a + b - 200 = 0
#Функция Лагранжа :
#3*a**2 + a + 5*b**2 + 4*b + w*(a + b - 200)
#df/da = 6*a + w + 1 = 0
#df/db = 10*b + w + 4 = 0
#df/dw = a + b - 200 = 0
#Стационарная точка M(x,y):
#125.1875 , 74.8125
# Out:
# Целевая функция для аргументов a и b :
#  f =  3*a**2 + a + 5*b**2 + 4*b
# Функция ограничений:  a + b - 200 = 0
# Функция Лагранжа :
#   3*a**2 + a + 5*b**2 + 4*b + w*(a + b - 200)
# df/da = 6*a + w + 1 = 0
# df/db = 10*b + w + 4 = 0
# df/dw = a + b - 200 = 0
# Стационарная точка M(x,y):
#  125.1875 , 74.8125

# %%
from sympy import *
x,y,w=symbols(' x y w' )
g = ((x-2)**2+(y-1)**2)**(0.5)
q = x + y - 1
f = ((x-2)**2+(y-1)**2)**(0.5) + w*(x + y - 1)
fx = f.diff(x)
fy = f.diff(y)
fw = f.diff(w)
sols = solve([fx,fy,fw],x,y,w)
sols
# Out:
# [(1.00000000000000, 0.0, 0.707106781186548)]

# %%
from sympy import *
x,y,w=symbols(' x y w' )
x_0 = 2
y_0 = 1
f = ((x - x_0) ** 2 + (y - y_0) ** 2) ** 0.5 + w * (x + y - 1)
solution = solve([f.diff(x), f.diff(y), f.diff(w)], x, y, w, dict=True)
print((solution[0][x] - x_0) ** 2 + (solution[0][y] - y_0) ** 2)
# Out:
# 2.00000000000000

# %%
from sympy import *

a,b,c,w=symbols('a b c w')
g = 2*(a*b + a*c + b*c)

L = 2*(a*b + a*c + b*c) + w*(a*b*c - 1)

L_a = L.diff(a)
L_b = L.diff(b)
L_c = L.diff(c)
L_w = L.diff(w)

print(solve([L_a, L_b, L_c, L_w], a, b, c, w)[0])
# Out:
# (1, 1, 1, -4)

# %%
from sympy import *
x, y, z, l = symbols('x y z l')
f = 2*(x*y + x*z + y*z)
f_o = x*y*z - 1
f_l = 2*(x*y + x*z + y*z) + l*(x*y*z - 1)
fx = diff(f_l, x)
fy = diff(f_l, y)
fz = diff(f_l, z)
fl = diff(f_l, l)
sols = solve([fx, fy, fz, fl], x, y, z, l)[0]
sols
print(f'Минимальная площадь: {f.subs({x:sols[0], y:sols[1], z:sols[2]})}')
print(sols)
# Out:
# Минимальная площадь: 6
# (1, 1, 1, -4)

# %%
# Импортируем все необходимые функции из библиотеки SymPy
from sympy import init_printing, solve, symbols

# Подключаем аккуратный вывод формул
init_printing()

# Создаём переменные
x1, x2, x1_tilde, lambda1, lambda2 = symbols(
    "x_1 x_2 xtilde_2 \lambda_1 \lambda_2", real=True
)

# Пишем систему уравнений для переменных
dLdx1 = -x2 + lambda1 - lambda2
dLdx2 = -x1 + lambda1
dLdx1_tilde = 2 * lambda2 * x1_tilde
dLdlambda1 = x1 + x2 - 10
dLdlambda2 = -x1 + 6 + x1_tilde**2

# Решаем систему уравнений с помощью функции solve
solution = solve(
    [dLdx1, dLdx2, dLdx1_tilde, dLdlambda1, dLdlambda2],
    x1,
    x2,
    x1_tilde,
    lambda1,
    lambda2,
)

print(solution)
# Out:
# [(6, 4, 0, 6, 2)]

# %%
from sympy import *
x, y, z, l = symbols('x y z l')
f = x**2*y+4*y+x*y
fx = diff(f, x)
fy = diff(f, y)
fz = diff(f, z)
fx
fy
# Out:
#  2
# x  + x + 4

# %%
from sympy import *
x, y, z, l = symbols('x y z l')
f = x**2-x*y
fx = diff(f, x)
fy = diff(f, y)
fz = diff(f, z)
fx
#fy
# Out:
# 2⋅x - y

# %%
from sympy import *
x, y, z, l = symbols('x y z l')
f = x-x*y+z**2
fx = diff(f, x)
fy = diff(f, y)
fz = diff(f, z)
print([fx],[fy],[fz])
print(fx,fy,fz)
# Out:
# [1 - y] [-x] [2*z]
# 1 - y -x 2*z

# %%
import numpy as np

# %%
f = np.array([3, 7, 14, 23, 36, 47], dtype=float)
 
np.gradient(f,1)

# array([ 4. ,  5.5,  8. , 11. , 12. , 11. ])
# Out:
# array([ 4. ,  5.5,  8. , 11. , 12. , 11. ])

# %%
print(f[1] - f[0], f[-1] - f[-2])
# Out:
# 4.0 11.0

# %%
(f[2] - f[0])/2 # 5.5
(f[3] - f[1])/2 # 8.0
(f[4] - f[2])/2 # 11.0
(f[5] - f[3])/2 # 12.0
# Out:
# 12.0

# %%
from sympy import *
x, y, z, l = symbols('x y z l')
f = (5-x-2*y)**2
fx = diff(f, x)
fy = diff(f, y)
fz = diff(f, z)
print([fx],[fy],[fz])
print(fx,fy,fz)
# Out:
# [2*x + 4*y - 10] [4*x + 8*y - 20] [0]
# 2*x + 4*y - 10 4*x + 8*y - 20 0

# %%
from sympy import *
x, y, z, l = symbols('x y z l')
f = (2.1-x-y)**2+(2.9-x-3*y)**2+(4.1-x-5*y)**2
fx = diff(f, x)
fy = diff(f, y)
fz = diff(f, z)
print([fx],[fy],[fz])
print(fx,fy,fz)
# Out:
# [6.0*x + 18.0*y - 18.2] [18.0*x + 70.0*y - 62.6] [0]
# 6.0*x + 18.0*y - 18.2 18.0*x + 70.0*y - 62.6 0

# %%
f = np.array([8, 2, 8, 3, 5, 6, 5, 15], dtype=float)
 
np.gradient(f,7)[7]
# Out:
# 1.4285714285714286

# %%
def fun(x, y, a=1, b=1):
    return a * (x ** 2) + b * (y ** 2)

# %%
def grad(x, y, a=1, b=1):
    return np.array([2 * a * x, 2 * b * y])

# %%
def grad_descend(grad, step_size=0.2, num_steps=30):
    lst = []
    x = np.random.uniform(0, 3, size = 2)
    lst.append(x)
    for i in range(num_steps):
        x = x - step_size * grad(lst[-1][0], lst[-1][1])
        lst.append(x)
    return np.array(lst)

# %%
def plot_grad(fun, trace):
    fig = plt.figure(figsize=(10, 8))
    x_ = np.linspace(-1, 1, 100)
    y_ = np.linspace(-1, 1, 100)
    x, y = np.meshgrid(x_, y_)
    z = fun(x, y)
    ax = fig.add_subplot(1, 1, 1, projection='3d')
    ax.plot_surface(x, y, z, alpha=0.6)
    ax.contour(x, y, z, zdir='z', offset=z.min())
    z_trace = fun(trace[:, 0], trace[:, 1])
    ax.plot(trace[:, 0], trace[:, 1], z_trace, "o-")
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(y.min(), y.max())
    ax.set_zlim(z.min(), z.max())

# %%
trace = grad_descend(grad, 0.1, 20)
plot_grad(fun, trace = trace)

# %%
from sympy import *
x, y, z, l = symbols('x y z l')
f = 2*x**2-4*x*z+4*y**2-8*y*z+9*z**2+4*x+8*y-20*z
fx = diff(f, x)
fy = diff(f, y)
fz = diff(f, z)
print([fx],[fy],[fz])
print(fx,fy,fz)
# Out:
# [4*x - 4*z + 4] [8*y - 8*z + 8] [-4*x - 8*y + 18*z - 20]
# 4*x - 4*z + 4 8*y - 8*z + 8 -4*x - 8*y + 18*z - 20
