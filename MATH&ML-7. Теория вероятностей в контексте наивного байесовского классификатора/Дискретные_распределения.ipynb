# %% [markdown]
# ## Равномерное распределение

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
from scipy.stats import randint

# %%
x = np.arange(1, 7)
disc_uni_dist = randint(1, 7)
pmf = disc_uni_dist.pmf(x)
print(pmf)
# Out:
# [0.16666667 0.16666667 0.16666667 0.16666667 0.16666667 0.16666667]

# %%
cdf = disc_uni_dist.cdf(x)
print(cdf)
# Out:
# [0.16666667 0.33333333 0.5        0.66666667 0.83333333 1.        ]

# %%
x = np.arange(1, 251)
disc_uni_dist = randint(1,251)
cdf = disc_uni_dist.cdf(x)
print(cdf[10])
# Out:
# 0.044

# %% [markdown]
# ## Распределение Бернулли

# %%
from scipy.stats import bernoulli
import seaborn as sns

# %%
data = bernoulli.rvs(size=500,p=0.6)
ax = sns.distplot(data,
                  kde = False,
                  color='dodgerblue')
ax.set(xlabel='Значение случайной величины', ylabel='Частота')
# Out:
# [Text(0.5, 0, 'Значение случайной величины'), Text(0, 0.5, 'Частота')]

# %%
unique, counts = np.unique(data, return_counts=True)
print(np.asarray((unique, counts)).T)
# Out:
# [[  0 209]
#  [  1 291]]

# %% [markdown]
# ## Биномиальное распределение

# %%
from numpy import random

# %%
x = random.binomial(n=10, p=0.5, size=1000)
sns.distplot(random.binomial(n=10, p=0.5, size=1000), hist=True, kde=False)
# Out:
# <Axes: >

# %% [markdown]
# ## Распределение Пуассона

# %%
import scipy

# %%
scipy.stats.distributions.poisson.pmf(5, 4.5)
# Out:
# 0.17082685848611215

# %%
sns.distplot(random.poisson(lam=3, size=1000), kde=False)
# Out:
# <Axes: >

# %%
A = np.matrix ("14.3,21.2,8.34,15.32;4.3,3.1,0.36,12.42;18.6,24.3,8.7,27.74")
b = np.array([133.18,178.6,56.7,145.9])
G = np.dot(A.T, A)
G
# Out:
# matrix([[ 568.94  ,  768.47  ,  282.63  ,  788.446 ],
#         [ 768.47  , 1049.54  ,  389.334 , 1037.368 ],
#         [ 282.63  ,  389.334 ,  145.3752,  373.578 ],
#         [ 788.446 , 1037.368 ,  373.578 , 1158.4664]])

# %%
Ainv = np.linalg.inv(G)
Ainv
# Out:
# matrix([[-1.12302485e+13,  8.92469642e+12, -6.84528751e+12,
#           1.85892216e+12],
#         [ 3.14941328e+12, -6.87353722e+12,  1.15380398e+13,
#           2.90804667e+11],
#         [ 5.86406201e+12,  4.95816644e+12, -1.75921860e+13,
#          -2.75785794e+12],
#         [ 2.93203101e+12, -1.51796853e+12,  0.00000000e+00,
#          -6.36234371e+11]])

# %%
c = np.dot(A.T, b)
c
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 c = np.dot(A.T, b)
#       2 c
#
# ValueError: shapes (4,3) and (4,) not aligned: 3 (dim 1) != 4 (dim 0)

# %%
A = np.column_stack((np.ones(506), CRIM, RM))
y = boston_data[['PRICE']]
print(A)
w_hat = np.linalg.inv(A.T@A)@A.T@y
print(w_hat.values)

# %%
AA = np.array([1,3,5])
BB=np.array([2.1,2.9,4.1])
CC = np.linalg.inv(AA.T@AA)@AA.T@BB
print(CC.values)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[20], line 3
#       1 AA = np.array([1,3,5])
#       2 BB=np.array([2.1,2.9,4.1])
# ----> 3 CC = np.linalg.inv(AA.T@AA)@AA.T@BB
#       4 print(CC.values)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\linalg\linalg.py:555, in inv(a)
#     494 """
#     495 Compute the (multiplicative) inverse of a matrix.
#     496
#    (...)
#     552
#     553 """
#     554 a, wrap = _makearray(a)
# --> 555 _assert_stacked_2d(a)
#     556 _assert_stacked_square(a)
#     557 t, result_t = _commonType(a)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\linalg\linalg.py:206, in _assert_stacked_2d(*arrays)
#     204 for a in arrays:
#     205     if a.ndim < 2:
# --> 206         raise LinAlgError('%d-dimensional array given. Array must be '
#     207                 'at least two-dimensional' % a.ndim)
#
# LinAlgError: 0-dimensional array given. Array must be at least two-dimensional
