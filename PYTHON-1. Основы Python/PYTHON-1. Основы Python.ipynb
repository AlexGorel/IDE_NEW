# %% [markdown]
# # 1. Введение

# %% [markdown]
# Приветствуем вас! ⭐
#
# С этого модуля мы приступаем к погружению в мир программирования и Data Science, и начинаем мы со знакомства с **основными понятиями IT** и с языком Python. Язык Python является в настоящее время основным языком для обработки и анализа данных, и именно поэтому Python будет одним из ваших основных рабочих инструментов. С его помощью вам предстоит решать множество задач: от подготовки датасета к анализу до тренировки ML-моделей.
#
# Возможно, вы прежде никогда не сталкивались с разработкой программ, но в этом нет ничего страшного — наше обучение построено так, чтобы помочь вам с нуля освоить все необходимые навыки, которые потребуются в вашей профессиональной деятельности.
# В этом модуле вы:
#
# ![image.png](attachment:image.png) познакомитесь с ключевыми понятиями IT;
#
# ![image.png](attachment:image.png) узнаете, что такое языки программирования и язык Python в частности;
#
# ![image.png](attachment:image.png) поймёте, почему Python — один из самых популярных языков программирования и почему его выбирают программисты и компании по всему миру;
#
# ![image.png](attachment:image.png) узнаете, для чего нужна документация по Python, и потренируетесь с ней работать;
#
# ![image.png](attachment:image.png) напишете свою первую программу на Python;
#
# ![image.png](attachment:image.png) познакомитесь с первыми функциями, с помощью которых можно будет выводить информацию на экран и запрашивать информацию у пользователя;
#
# ![image.png](attachment:image.png) узнаете, что такое переменные и типы данных;
#
# ![image.png](attachment:image.png) поработаете с числовыми типами данных и строками.
#
# В модуле вас ждёт множество новых понятий. Чтобы вам было проще их запомнить, мы собрали их в разделе [«Термины»](https://lms.skillfactory.ru/courses/course-v1:SkillFactory+DST-3.0+28FEB2021/15b071d378e34ebf84029ad50485e99a/). Смело используйте этот раздел для повторения, а также если встретите в курсе уже знакомый термин, значение которого забыли.
#
# Готовы приступать? Тогда вперёд!

# %% [markdown]
# # 2. Введение в программирование на Python

# %% [markdown]
# Мы приступаем к изучению языка программирования Python. В этом юните мы:
# * разберём основные понятия из мира языков программирования (ЯП);
# * рассмотрим классификацию ЯП;
# * на основе этой классификации поймём, чем Python отличается от других языков программирования и в чём он схож с ними;
# * посмотрим, какие у него есть преимущества и недостатки в сравнении с другими языками;
# * поймём, почему его выбирают компании и разработчики;
# * узнаем, почему у Python есть несколько версий, какие из них актуальны, а какие безнадёжно устарели.
#
# **Почему это важно знать?**
#
# Кто-то из вас уже знает основы программирования, а кто-то только начинает свой путь. В любом случае важно или освежить знания, или познакомиться с новыми понятиями. Часть этой информации понадобится вам при дальнейшем изучении курса и в работе, а часть поможет повысить общую эрудицию в программировании — вам будет понятно, о чём говорят ваши коллеги и другие программисты.
#
# #### Python среди других языков программирования
#
# Начнём с определения языка Python.
#
# **Python** — это высокоуровневый интерпретируемый кроссплатформенный язык программирования.
#
# В этом юните мы шаг за шагом разберём все эти понятия.
#
# #### Понятие «язык программирования»
#
# Начнём с определения термина «язык программирования».
#
# **Язык** программирования — это строго определённый набор правил, благодаря которому возможно взаимодействие человека с компьютером. Иначе говоря, язык программирования — это инструмент, с помощью которого вы можете управлять компьютером.
#
# Все программы, все операции, которые выполняют компьютеры, — результат следования инструкциям, которые для компьютеров пишут люди.
#
# Представьте, что общаетесь с иностранцем, который не знает вашего языка, но вы знаете его язык. Компьютер и есть наш «иностранец».
#
# #### ПОНЯТИЕ «ВЫСОКОУРОВНЕВЫЙ ЯЗЫК»
#
# Люди придумали много языков для общения с компьютером. Это было сделано по разным причинам:
#
# ![image.png](attachment:image.png) Иногда нам очень важна скорость работы программы, и тогда инструкцию компьютеру надо давать на максимально понятном для него языке, чтобы не тратить время на перевод.
#
# ![image.png](attachment:image.png) Иногда нам важнее, чтобы человек быстрее писал программы, и мы готовы уступить в скорости выполнения программы в пользу скорости написания.
#
# По этому критерию языки программирования разделяются на две категории: **высокоуровневые** и **низкоуровневые**.
#
# |Низкоуровневые языки|	Высокоуровневые языки|
# |-----|-----|
# |Созданы для удовлетворения нужд конкретной компьютерной архитектуры и учитывают требования «железа», поэтому скорость их работы, в отличие от высокоуровневых, выше.|	Созданы с расчётом на то, что их должны понимать люди и с ними должно быть удобно работать. Они независимы: программистам не нужно в точности знать, на каком именно оборудовании будет запускаться их программа. В случае с высокоуровневыми языками программирования скорость выполнения программы компенсируется скоростью её написания.|
# |Однако работать с ними достаточно тяжело, поэтому они применяются редко и только для узкоспециализированных задач.|За удобство пользования приходится платить памятью. Программы, написанные на высокоуровневых языках, требуют для своей работы и хранения значительно больше памяти, чем программы, написанные на низкоуровневых языках.|
# |Примеры низкоуровневых языков: Assembler, CIL|	Примеры высокоуровневых языков: Python, C++, Java, Kotlin, C#, JavaScript, PHP и многие другие.|
#
# **ПОНЯТИЕ «ИНТЕРПРЕТИРУЕМЫЙ ЯЗЫК»**
#
# Разработчики постоянно оперируют понятиями компилятор и интерпретатор — вы можете встретить их упоминание в документации, книгах, в курсе и в общении с коллегами. Начинающим разработчикам важно разобраться с тем, что стоит за этими терминами, поскольку компиляция и интерпретация являются одними из основных понятий в мире языков программирования.
#
# Чтобы объяснить их значение, нам придётся зайти издалека и ввести два дополнительных понятия: машинный код и транслятор.
#
# Машинный код (ещё его называют машинный язык) — это набор команд, которые непосредственно выполняются центральным процессором компьютера.
#
# Компьютеры работают с программами, написанными непосредственно на машинном языке для данной аппаратной и программной платформы...
# Сейчас мало кто пишет программы напрямую в машинном коде, хотя раньше он был практически единственным инструментом программиста. С появлением языков высокого уровня необходимость писать программы в машинном коде отпала. К тому же это достаточно непросто и часто приводит к ошибкам, поскольку разработчику при написании программ необходимо управлять отдельными битами и вычислять числовые адреса и константы вручную.
#
# Для того чтобы программистам не было нужды погружаться в изучение и работу с машинным языком, а можно было работать исключительно с языками высокого уровня, были разработаны особые виды программ — трансляторы.
#
# Транслятор — это программа, которая выполняет преобразование программы, написанной на высокоуровневом языке программирования, в программу, состоящую из машинных команд.
#
# Можно сказать, что трансляторы — это переводчики программ с языков высокого уровня на машинный язык, с которым может работать процессор. В этом контексте машинный код является целевым языком или объектным кодом. Язык, с которого осуществляется перевод, называется исходным, а программа на нём — исходным кодом.
#
# ![image-2.png](attachment:image-2.png)
#
# Существует две разновидности трансляторов: компиляторы и интерпретаторы. И, соответственно, языки программирования, использующие тот или иной подход к исполнению программ, называются компилируемыми или интерпретируемыми.
#
# **Компилятор**
#
# Компилятор выполняет преобразование (компиляцию) программы, написанной на языке высокого уровня (исходный язык), в машинный код.
#
# Затем этот код записывается в исполняемый файл (например, .exe-файл), который уже можно запустить, как и любую другую обычную программу на вашем компьютере.
#
# Компиляция выполняется единожды, а исполняемый файл (программа) может использоваться в системе, под которую была выполнена компиляция, сколько угодно раз.
#
# Поскольку у компьютера при последующих запусках не уходит время на преобразование исходного кода в машинный, то программы, написанные на компилируемых языках, работают эффективнее и быстрее.
#
# Однако если будет необходимо внести изменения в исходный код, это потребует и повторной компиляции, а процесс компиляции достаточно медленный.
#
# **Интерпретатор**
#
# Интерпретатор напрямую выполняет текст кода без его предварительного преобразования в машинный код.
#
# Каждая строка исходного кода переводится в машинный код за один проход интерпретатора.
#
# В данном случае программа в машинном коде существует только во время интерпретации и не сохраняется в виде отдельного файла.
#
# Программа всегда остаётся на исходном языке, и её нельзя выполнить без использования интерпретатора.
#
# Схематично работу компилятора и интерпретатора можно изобразить так:
#
# ![image-3.png](attachment:image-3.png)
#
# **ПОНЯТИЕ «КРОССПЛАТФОРМЕННЫЙ ЯЗЫК»**
#
# Это понятие тесно связано с предыдущим.
#
# Кроссплатформенность, или платформонезависимость — это способность программы работать более чем на одной аппаратной платформе или в более чем одной операционной системе.
#
# Кроссплатформенность — главное преимущество интерпретируемых языков. Оно позволяет применять продвинутые приёмы динамического программирования, например метапрограммирование (подробнее про метапрограммирование можно прочитать в этой [статье](https://habr.com/ru/articles/137446/)).
#
# Компилируемые языки являются платформозависимыми: результирующий машинный код зависит от программной и аппаратной платформы компьютера, на котором была скомпилирована программа. Это означает, что программа, скомпилированная под Windows, не запустится на Linux или MacOS без дополнительных манипуляций и наоборот.
#
# Надеемся, что теперь фраза «Python — это высокоуровневый интерпретируемый кроссплатформенный язык программирования» стала для вас более понятной.
#
# СИНТАКСИС ЯЗЫКА ПРОГРАММИРОВАНИЯ
#
# Напоследок разберём ещё одно важное понятие из мира языков программирования — синтаксис языка программирования.
#
# Синтаксис языка программирования — это набор правил, на основе которых строится программа.
#
# → Если проводить аналогию с русским языком, синтаксис — это правила орфографии и пунктуации. В языке программирования есть строго определённый набор ключевых слов, которые описывают команды для компьютера. В этих словах важен каждый символ: любое несоответствие или неоднозначность в вашем коде вызовет ошибку.
#
# → Кроме того, важна и структура кода, который вы пишите, — это можно сравнить с логичностью повествования. Например, если мы рассказываем соседу о том, как нам удалось вырастить сад на нашем садовом участке, и говорим, что сначала дерево выросло, а потом мы посадили семечко, то воспроизведение таких действий будет лишено всякого смысла и не может быть выполнено нашим соседом. С программами аналогично: если будет нарушена структура кода, то инструкция не может быть выполнена компьютером.
