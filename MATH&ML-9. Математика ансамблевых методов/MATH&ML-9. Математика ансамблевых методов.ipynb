# %%
import numpy as np

# %%
a = np.array([4.4, 3.8, 4.8, 4.0, 3.4, 4.2, 5.2])
b = a.mean()
np.sum((a - b)**2)/7
b
# Out:
# 4.257142857142857

# %% [markdown]
# Задание 2.7
# 0.0/2.0 points (graded)
# Подготовьте данные к классификации. Условно разделите вино на хорошее и плохое. Хорошим вином будем называть то, параметр quality которого — 6 и более.
# Разделите выборку на обучающую и тестовую в соотношении 70/30, в качестве значения параметра random_state возьмите число 42.
# Для начала обучите два классификатора: логистическую регрессию (с параметрами по умолчанию) и дерево решений (random_state = 42, максимальная глубина — 10).

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from sklearn import tree
from sklearn import model_selection
from sklearn import metrics
from sklearn import linear_model

# %%
df_2_7 = pd.read_csv('C:\скил\DST-156\IDE_NEW\MATH&ML-9. Математика ансамблевых методов/wineQualityReds.csv')
df_2_7.head()
# Out:
#    Unnamed: 0  fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# 0           1            7.4              0.70         0.00             1.9
# 1           2            7.8              0.88         0.00             2.6
# 2           3            7.8              0.76         0.04             2.3
# 3           4           11.2              0.28         0.56             1.9
# 4           5            7.4              0.70         0.00             1.9
#
#    chlorides  free.sulfur.dioxide  total.sulfur.dioxide  density    pH  \
# 0      0.076                 11.0                  34.0   0.9978  3.51
# 1      0.098                 25.0                  67.0   0.9968  3.20
# 2      0.092                 15.0                  54.0   0.9970  3.26
# 3      0.075                 17.0                  60.0   0.9980  3.16
# 4      0.076                 11.0                  34.0   0.9978  3.51
#
#    sulphates  alcohol  quality
# 0       0.56      9.4        5
# 1       0.68      9.8        5
# 2       0.65      9.8        5
# 3       0.58      9.8        6
# 4       0.56      9.4        5

# %%
df_2_7['target']= np.where(df_2_7.quality >=6,1,0)

# %%
y= df_2_7['target']
X =df_2_7.drop(['quality','target'],axis=1)

# Формируем обучающую и тестовую выборки
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)
#print('Train shape: {}'.format(X_train.shape))
#print('Test shape: {}'.format(X_test.shape))

# %%
# Инициализируем модель дерева решений с максимальной глубиной 1 и обучаем ее
dt_2_7 = tree.DecisionTreeClassifier(
    max_depth=10, #глубина
    #criterion='entropy', #критерий информативности
    random_state=42 #генератор случайных чисел
)
dt_2_7.fit(X_train, y_train)
# Визуализируем дерево решений в виде графа
#tree.plot_tree(
    #decision_tree=dt_7_2, #дерево решений 
    #feature_names=X.columns, #имена факторов
    #proportion=True, #выводить ли количество данных в пропорциях
    #filled=True, #расцветка
    #impurity=True, #отображать ли неоднородность в вершинах
    #class_names=dt_7_2.classes_, #имена классов

# Делаем предсказание
y_train_pred_2_7 = dt_2_7.predict(X_train)
y_test_pred_2_7 = dt_2_7.predict(X_test)
# Считаем метрику accuracy на тестовой выборке
print('F1_test: {:.3f}'.format(metrics.f1_score(y_test, y_test_pred_2_7)))
print('F1_train: {:.3f}'.format(metrics.f1_score(y_train, y_train_pred_2_7)))
# Out:
# F1_test: 0.766
# F1_train: 0.935

# %%
# Инициализируем модель дерева решений с максимальной глубиной 1 и обучаем ее
dt_2_7 = linear_model.LogisticRegression()
dt_2_7.fit(X_train, y_train)
# Визуализируем дерево решений в виде графа
#tree.plot_tree(
    #decision_tree=dt_7_2, #дерево решений 
    #feature_names=X.columns, #имена факторов
    #proportion=True, #выводить ли количество данных в пропорциях
    #filled=True, #расцветка
    #impurity=True, #отображать ли неоднородность в вершинах
    #class_names=dt_7_2.classes_, #имена классов

# Делаем предсказание
y_train_pred_2_7 = dt_2_7.predict(X_train)
y_test_pred_2_7 = dt_2_7.predict(X_test)
# Считаем метрику accuracy на тестовой выборке
print('F1_test: {:.3f}'.format(metrics.f1_score(y_test, y_test_pred_2_7)))
print('F1_train: {:.3f}'.format(metrics.f1_score(y_train, y_train_pred_2_7)))
# Out:
# F1_test: 0.767
# F1_train: 0.753
# C:\Users\molde\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
df_2_7['target']= np.where(df_2_7.quality >=6,1,0)
Y= df_2_7['target']
X = df_2_7.drop(['target', 'quality'], axis= 1)
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, Y, test_size=0.3, random_state=42)
model = linear_model.LogisticRegression()
model.fit(X_train, y_train)
preds_train = model.predict(X_train)
preds_test = model.predict(X_test)
print(metrics.f1_score(preds_test, y_test))
model = tree.DecisionTreeClassifier(max_depth = 10, random_state=42)
model.fit(X_train, y_train)
preds_train = model.predict(X_train)
preds_test = model.predict(X_test)
print(metrics.f1_score(preds_test, y_test))
# Out:
# 0.7390476190476191
# 0.7601476014760148
# C:\Users\molde\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Задание 2.8
#
# 1 point possible (graded)
#
# Обучите модель с использованием бэггинга (класс BaggingClassifier с random_state=42).
#
#
# Возьмите из предыдущего задания алгоритм, показавший наилучшее качество, и укажите для него новое количество моделей — 1500. Вычислите новое значение F1-score.

# %%
from sklearn.ensemble import BaggingClassifier
df_2_7['target']= np.where(df_2_7.quality >=6,1,0)
Y= df_2_7['target']
X = df_2_7.drop(['target', 'quality'], axis= 1)
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, Y, test_size=0.3, random_state=42)
model_2_8 = BaggingClassifier(
    estimator=tree.DecisionTreeClassifier(max_depth = 10, random_state=42),
    n_estimators=1500,
    random_state=42)
model_2_8.fit(X_train, y_train)
preds_train_2_8 = model_2_8.predict(X_train)
preds_test_2_8 = model_2_8.predict(X_test)
print( round(     (metrics.f1_score(preds_test_2_8, y_test)),3     ))
# Out:
# 0.824

# %% [markdown]
# Задание 3.4
#
# 0.0/4.0 points (graded)
# 1. Разбейте набор данных на обучающую и тестовую выборку в соотношении 70/30, при разбиении задайте параметр random_state = 13.
#
# Какое получилось среднее значение медианных цен на обучающей выборке? Ответ округлите до двух знаков после точки-разделителя.
#
#   нет ответа
#
# 2. Обучите линейную регрессию с параметрами по умолчанию.
#
# В качестве ответа введите ошибку MAE на тестовой выборке. Ответ округлите до двух знаков после точки-разделителя.
#
#   нет ответа
#
#
# 3. Обучите решающее дерево с параметрами по умолчанию и аргументом random_state = 13.
#
# Можно ли, опираясь на результаты, сделать вывод, что алгоритм переобучился?
#
# Да
# Нет
# нет ответа
# 4. Обучите четыре случайных леса с числом деревьев 3, 10, 100, 500 и параметром random_state = 13.
#
# В качестве ответа введите наименьшую полученную ошибку MAE на тестовой выборке. Ответ округлите до двух знаков после точки-разделителя.
#
#   нет ответа
#
# Отправить

# %%
df_3_4 = pd.read_csv('C:\скил\DST-156\IDE_NEW\MATH&ML-9. Математика ансамблевых методов/boston (1).csv', decimal=',')
df_3_4.head()
# Out:
#    crim_rate    zn  business  river  nit_oxiden  rooms   age    dist  \
# 0    0.00632  18.0      2.31      0       0.538  6.575  65.2  4.0900
# 1    0.02731   0.0      7.07      0       0.469  6.421  78.9  4.9671
# 2    0.02729   0.0      7.07      0       0.469  7.185  61.1  4.9671
# 3    0.03237   0.0      2.18      0       0.458  6.998  45.8  6.0622
# 4    0.06905   0.0      2.18      0       0.458  7.147  54.2  6.0622
#
#    highways_index  tax  pup_per_teaс  lower  target
# 0               1  296          15.3   4.98    24.0
# 1               2  242          17.8   9.14    21.6
# 2               2  242          17.8   4.03    34.7
# 3               3  222          18.7   2.94    33.4
# 4               3  222          18.7   5.33    36.2

# %%
df_3_4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   crim_rate       506 non-null    float64
#  1   zn              506 non-null    float64
#  2   business        506 non-null    float64
#  3   river           506 non-null    int64
#  4   nit_oxiden      506 non-null    float64
#  5   rooms           506 non-null    float64
#  6   age             506 non-null    float64
#  7   dist            506 non-null    float64
#  8   highways_index  506 non-null    int64
#  9   tax             506 non-null    int64
#  10  pup_per_teaс    506 non-null    float64
#  11  lower           506 non-null    float64
#  12  target          506 non-null    float64
# dtypes: float64(10), int64(3)
# memory usage: 51.5 KB

# %%
import pandas as pd
Y= df_3_4['target']
X = df_3_4.drop('target', axis= 1)
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, Y, test_size=0.3, random_state=13)
round(y_train.mean(),2)
# Out:
# 22.77

# %%
model_3_4 = linear_model.LinearRegression()
model_3_4.fit(X_train, y_train)
preds_train_3_4 = model_3_4.predict(X_train)
preds_test_3_4 = model_3_4.predict(X_test)
print(     round(metrics.mean_absolute_error(preds_test_3_4, y_test),2))
# Out:
# 3.72

# %%
model_3_4_1 = tree.DecisionTreeRegressor(random_state=13)
model_3_4_1.fit(X_train, y_train)
preds_train_3_4_1 = model_3_4_1.predict(X_train)
preds_test_3_4_1 = model_3_4_1.predict(X_test)
print( round(     (metrics.mean_absolute_error(preds_test_3_4_1, y_test)),3     ))
print( round(     (metrics.mean_absolute_error(preds_train_3_4_1, y_train)),3     ))
# Out:
# 2.839
# 0.0

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
for n in [3, 10, 100, 500]:
    model_3_4_2 = RandomForestRegressor(n_estimators=n,random_state=13)
    model_3_4_2.fit(X_train, y_train)
    preds_train_3_4_2 = model_3_4_2.predict(X_train)
    preds_test_3_4_2 = model_3_4_2.predict(X_test)
    print( round(     (metrics.mean_absolute_error(preds_test_3_4_2, y_test)), 2    ))
# Out:
# 2.93
# 2.47
# 2.26
# 2.24

# %% [markdown]
# 4. Случайный лес. Практика

# %% [markdown]
# weatherAUS

# %%
data = pd.read_csv('C:\скил\DST-156\IDE_NEW\MATH&ML-9. Математика ансамблевых методов/weatherAUS.csv', decimal=',')
data.head()
# Out:
#          Date Location MinTemp MaxTemp Rainfall Evaporation Sunshine  \
# 0  2008-12-01   Albury    13.4    22.9      0.6         NaN      NaN
# 1  2008-12-02   Albury     7.4    25.1        0         NaN      NaN
# 2  2008-12-03   Albury    12.9    25.7        0         NaN      NaN
# 3  2008-12-04   Albury     9.2      28        0         NaN      NaN
# 4  2008-12-05   Albury    17.5    32.3        1         NaN      NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am Cloud3pm Temp9am  Temp3pm  RainToday  \
# 0       1007.7       1007.1       8.0      NaN    16.9     21.8         No
# 1       1010.6       1007.8       NaN      NaN    17.2     24.3         No
# 2       1007.6       1008.7       NaN      2.0      21     23.2         No
# 3       1017.6       1012.8       NaN      NaN    18.1     26.5         No
# 4       1010.8         1006       7.0      8.0    17.8     29.7         No
#
#   RainTomorrow
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No
#
# [5 rows x 23 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  object
#  3   MaxTemp        144199 non-null  object
#  4   Rainfall       142199 non-null  object
#  5   Evaporation    82670 non-null   object
#  6   Sunshine       75625 non-null   object
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  object
#  16  Pressure3pm    130432 non-null  object
#  17  Cloud9am       89572 non-null   float64
#  18  Cloud3pm       86102 non-null   float64
#  19  Temp9am        143693 non-null  object
#  20  Temp3pm        141851 non-null  object
#  21  RainToday      142199 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(7), object(16)
# memory usage: 25.5+ MB

# %% [markdown]
# Задание 4.1
#
# 1/1 point (graded)
#
# Сколько суммарно пропусков в данных?

# %%
data.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %% [markdown]
# Задание 4.2
#
# 1/1 point (graded)
#
# В некоторых признаках пропусков более 40 % — удалите такие признаки. Сколько их было?

# %%
(data.isna().sum()/len(data)).sort_values(ascending=False)
# Out:
# Sunshine         0.480098
# Evaporation      0.431665
# Cloud3pm         0.408071
# Cloud9am         0.384216
# Pressure9am      0.103568
# Pressure3pm      0.103314
# WindDir9am       0.072639
# WindGustDir      0.070989
# WindGustSpeed    0.070555
# Humidity3pm      0.030984
# WindDir3pm       0.029066
# Temp3pm          0.024811
# RainTomorrow     0.022460
# Rainfall         0.022419
# RainToday        0.022419
# WindSpeed3pm     0.021050
# Humidity9am      0.018246
# Temp9am          0.012148
# WindSpeed9am     0.012148
# MinTemp          0.010209
# MaxTemp          0.008669
# Location         0.000000
# Date             0.000000
# dtype: float64

# %%
mask_1=data.isna().sum()/len(data)
mask_1.sort_values(ascending=False)
# Out:
# Sunshine         0.480098
# Evaporation      0.431665
# Cloud3pm         0.408071
# Cloud9am         0.384216
# Pressure9am      0.103568
# Pressure3pm      0.103314
# WindDir9am       0.072639
# WindGustDir      0.070989
# WindGustSpeed    0.070555
# Humidity3pm      0.030984
# WindDir3pm       0.029066
# Temp3pm          0.024811
# RainTomorrow     0.022460
# Rainfall         0.022419
# RainToday        0.022419
# WindSpeed3pm     0.021050
# Humidity9am      0.018246
# Temp9am          0.012148
# WindSpeed9am     0.012148
# MinTemp          0.010209
# MaxTemp          0.008669
# Location         0.000000
# Date             0.000000
# dtype: float64

# %%
data.drop(['Sunshine','Evaporation','Cloud3pm'],axis=1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  object
#  3   MaxTemp        144199 non-null  object
#  4   Rainfall       142199 non-null  object
#  5   WindGustDir    135134 non-null  object
#  6   WindGustSpeed  135197 non-null  float64
#  7   WindDir9am     134894 non-null  object
#  8   WindDir3pm     141232 non-null  object
#  9   WindSpeed9am   143693 non-null  float64
#  10  WindSpeed3pm   142398 non-null  float64
#  11  Humidity9am    142806 non-null  float64
#  12  Humidity3pm    140953 non-null  float64
#  13  Pressure9am    130395 non-null  object
#  14  Pressure3pm    130432 non-null  object
#  15  Cloud9am       89572 non-null   float64
#  16  Temp9am        143693 non-null  object
#  17  Temp3pm        141851 non-null  object
#  18  RainToday      142199 non-null  object
#  19  RainTomorrow   142193 non-null  object
# dtypes: float64(6), object(14)
# memory usage: 22.2+ MB

# %% [markdown]
# Задание 4.3
#
# 1 point possible (graded)
#
# Теперь обработаем признаки RainToday и RainTomorrow таким образом, чтобы вместо yes было значение 1, а вместо no — значение 0. Обратите внимание на то, что в признаках RainToday и RainTomorrow присутствуют пропуски, и их трогать не нужно, они должны остаться пропусками. Поэтому обрабатывайте столбцы таким образом, чтобы не видоизменить пропущенные значения.
#
# Вычислите среднее арифметическое для преобразованного признака RainToday и запишите его в ответ, предварительно округлив до двух знаков после точки-разделителя.

# %%
data.RainToday = data.RainToday.map({'No': 0, 'Yes': 1})
data.RainTomorrow = data.RainTomorrow.map({'No': 0, 'Yes': 1})
data.head(10)
# Out:
#          Date Location MinTemp MaxTemp Rainfall WindGustDir  WindGustSpeed  \
# 0  2008-12-01   Albury    13.4    22.9      0.6           W           44.0
# 1  2008-12-02   Albury     7.4    25.1        0         WNW           44.0
# 2  2008-12-03   Albury    12.9    25.7        0         WSW           46.0
# 3  2008-12-04   Albury     9.2      28        0          NE           24.0
# 4  2008-12-05   Albury    17.5    32.3        1           W           41.0
# 5  2008-12-06   Albury    14.6    29.7      0.2         WNW           56.0
# 6  2008-12-07   Albury    14.3      25        0           W           50.0
# 7  2008-12-08   Albury     7.7    26.7        0           W           35.0
# 8  2008-12-09   Albury     9.7    31.9        0         NNW           80.0
# 9  2008-12-10   Albury    13.1    30.1      1.4           W           28.0
#
#   WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  \
# 0          W        WNW          20.0          24.0         71.0         22.0
# 1        NNW        WSW           4.0          22.0         44.0         25.0
# 2          W        WSW          19.0          26.0         38.0         30.0
# 3         SE          E          11.0           9.0         45.0         16.0
# 4        ENE         NW           7.0          20.0         82.0         33.0
# 5          W          W          19.0          24.0         55.0         23.0
# 6         SW          W          20.0          24.0         49.0         19.0
# 7        SSE          W           6.0          17.0         48.0         19.0
# 8         SE         NW           7.0          28.0         42.0          9.0
# 9          S        SSE          15.0          11.0         58.0         27.0
#
#   Pressure9am Pressure3pm  Cloud9am Temp9am Temp3pm  RainToday  RainTomorrow
# 0      1007.7      1007.1       8.0    16.9    21.8        0.0           0.0
# 1      1010.6      1007.8       NaN    17.2    24.3        0.0           0.0
# 2      1007.6      1008.7       NaN      21    23.2        0.0           0.0
# 3      1017.6      1012.8       NaN    18.1    26.5        0.0           0.0
# 4      1010.8        1006       7.0    17.8    29.7        0.0           0.0
# 5      1009.2      1005.4       NaN    20.6    28.9        0.0           0.0
# 6      1009.6      1008.2       1.0    18.1    24.6        0.0           0.0
# 7      1013.4      1010.1       NaN    16.3    25.5        0.0           0.0
# 8      1008.9      1003.6       NaN    18.3    30.2        0.0           1.0
# 9        1007      1005.7       NaN    20.1    28.2        1.0           0.0

# %%
round( data['RainToday'].mean(),2)
# Out:
# 0.22

# %% [markdown]
# Задание 4.4
#
# 1 point possible (graded)
#
# Обработайте признак Date таким образом, чтобы выделить в отдельный признак Month (номер месяца). Изначальный признак Date удалите. Определите, какой месяц имеет самую большую часть дождливых дней относительно всех дней месяца. В качестве ответа введите порядковый номер месяца.

# %%
data['Date']=pd.to_datetime(data['Date'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  datetime64[ns]
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  object
#  3   MaxTemp        144199 non-null  object
#  4   Rainfall       142199 non-null  object
#  5   WindGustDir    135134 non-null  object
#  6   WindGustSpeed  135197 non-null  float64
#  7   WindDir9am     134894 non-null  object
#  8   WindDir3pm     141232 non-null  object
#  9   WindSpeed9am   143693 non-null  float64
#  10  WindSpeed3pm   142398 non-null  float64
#  11  Humidity9am    142806 non-null  float64
#  12  Humidity3pm    140953 non-null  float64
#  13  Pressure9am    130395 non-null  object
#  14  Pressure3pm    130432 non-null  object
#  15  Cloud9am       89572 non-null   float64
#  16  Temp9am        143693 non-null  object
#  17  Temp3pm        141851 non-null  object
#  18  RainToday      142199 non-null  float64
#  19  RainTomorrow   142193 non-null  float64
# dtypes: datetime64[ns](1), float64(8), object(11)
# memory usage: 22.2+ MB

# %%
# создание столбца year_month
data["Month"] = data["Date"].dt.month
# вывод объекта DataFrame
data
# Out:
#              Date Location MinTemp MaxTemp Rainfall WindGustDir  \
# 0      2008-12-01   Albury    13.4    22.9      0.6           W
# 1      2008-12-02   Albury     7.4    25.1        0         WNW
# 2      2008-12-03   Albury    12.9    25.7        0         WSW
# 3      2008-12-04   Albury     9.2      28        0          NE
# 4      2008-12-05   Albury    17.5    32.3        1           W
# ...           ...      ...     ...     ...      ...         ...
# 145455 2017-06-21    Uluru     2.8    23.4        0           E
# 145456 2017-06-22    Uluru     3.6    25.3        0         NNW
# 145457 2017-06-23    Uluru     5.4    26.9        0           N
# 145458 2017-06-24    Uluru     7.8      27        0          SE
# 145459 2017-06-25    Uluru    14.9     NaN        0         NaN
#
#         WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  ...  Humidity9am  \
# 0                44.0          W        WNW          20.0  ...         71.0
# 1                44.0        NNW        WSW           4.0  ...         44.0
# 2                46.0          W        WSW          19.0  ...         38.0
# 3                24.0         SE          E          11.0  ...         45.0
# 4                41.0        ENE         NW           7.0  ...         82.0
# ...               ...        ...        ...           ...  ...          ...
# 145455           31.0         SE        ENE          13.0  ...         51.0
# 145456           22.0         SE          N          13.0  ...         56.0
# 145457           37.0         SE        WNW           9.0  ...         53.0
# 145458           28.0        SSE          N          13.0  ...         51.0
# 145459            NaN        ESE        ESE          17.0  ...         62.0
#
#         Humidity3pm  Pressure9am Pressure3pm Cloud9am  Temp9am Temp3pm  \
# 0              22.0       1007.7      1007.1      8.0     16.9    21.8
# 1              25.0       1010.6      1007.8      NaN     17.2    24.3
# 2              30.0       1007.6      1008.7      NaN       21    23.2
# 3              16.0       1017.6      1012.8      NaN     18.1    26.5
# 4              33.0       1010.8        1006      7.0     17.8    29.7
# ...             ...          ...         ...      ...      ...     ...
# 145455         24.0       1024.6      1020.3      NaN     10.1    22.4
# 145456         21.0       1023.5      1019.1      NaN     10.9    24.5
# 145457         24.0         1021      1016.8      NaN     12.5    26.1
# 145458         24.0       1019.4      1016.5      3.0     15.1      26
# 145459         36.0       1020.2      1017.9      8.0       15    20.9
#
#        RainToday  RainTomorrow  Month
# 0            0.0           0.0     12
# 1            0.0           0.0     12
# 2            0.0           0.0     12
# 3            0.0           0.0     12
# 4            0.0           0.0     12
# ...          ...           ...    ...
# 145455       0.0           0.0      6
# 145456       0.0           0.0      6
# 145457       0.0           0.0      6
# 145458       0.0           0.0      6
# 145459       0.0           NaN      6
#
# [145460 rows x 21 columns]

# %%
data.drop(['Date'],axis=1,inplace=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 20 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       145460 non-null  object
#  1   MinTemp        143975 non-null  object
#  2   MaxTemp        144199 non-null  object
#  3   Rainfall       142199 non-null  object
#  4   WindGustDir    135134 non-null  object
#  5   WindGustSpeed  135197 non-null  float64
#  6   WindDir9am     134894 non-null  object
#  7   WindDir3pm     141232 non-null  object
#  8   WindSpeed9am   143693 non-null  float64
#  9   WindSpeed3pm   142398 non-null  float64
#  10  Humidity9am    142806 non-null  float64
#  11  Humidity3pm    140953 non-null  float64
#  12  Pressure9am    130395 non-null  object
#  13  Pressure3pm    130432 non-null  object
#  14  Cloud9am       89572 non-null   float64
#  15  Temp9am        143693 non-null  object
#  16  Temp3pm        141851 non-null  object
#  17  RainToday      142199 non-null  float64
#  18  RainTomorrow   142193 non-null  float64
#  19  Month          145460 non-null  int32
# dtypes: float64(8), int32(1), object(11)
# memory usage: 21.6+ MB

# %%
mask_4_4 = data.groupby('Month').mean(numeric_only=True)
mask_4_4['RainToday'].sort_values(ascending=False)
# Out:
# Month
# 7     0.270736
# 6     0.263638
# 8     0.253167
# 9     0.229135
# 5     0.222163
# 3     0.217135
# 4     0.216845
# 12    0.213037
# 11    0.210843
# 2     0.206746
# 10    0.196512
# 1     0.189484
# Name: RainToday, dtype: float64

# %% [markdown]
# Задание 4.5
#
# 1 point possible (graded)
#
# Обработайте оставшиеся категориальные признаки. С помощью метода get_dummies с настройками по умолчанию создайте dummy-переменные для всех категориальных признаков (их пять), которые есть в данных на этот момент.
#
# Кодировку признаков важно выполнить именно в следующем порядке: categoricals = ['Month', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']. Это необходимо для того, чтобы ваши дальнейшие ответы сходились с нашим решением, так как алгоритм случайного леса, который мы будем использовать в дальнейшем, чувствителен к порядку столбцов. Аргумент categoricals передаётся в функцию pd.get_dummies() с использованием ключевого слова columns, а именно columns=categoricals.
#
# Сколько теперь признаков в данных, если считать целевую переменную?

# %%
data_4_5=pd.get_dummies(data,columns=['Month', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])
data_4_5
#data_4_5.info()
data_4_5.shape
# Out:
# (145460, 124)

# %% [markdown]
# Задание 4.6
#
# 1 point possible (graded)
#
# Осталось совсем немного. Удалите все строки, где есть пропуски. Далее разбейте данные на обучающую и тестовую выборки в соотношении 70/30, в качестве значения параметра random_state возьмите число 31.
#
# Каково среднее значение целевой переменной на тестовой выборке? Ответ округлите до двух знаков после точки-разделителя.

# %%
data_4_5.isnull().sum()
# Out:
# MinTemp            1485
# MaxTemp            1261
# Rainfall           3261
# WindGustSpeed     10263
# WindSpeed9am       1767
#                   ...
# WindDir3pm_SSW        0
# WindDir3pm_SW         0
# WindDir3pm_W          0
# WindDir3pm_WNW        0
# WindDir3pm_WSW        0
# Length: 124, dtype: int64

# %%
data_cleaned=data_4_5.dropna(axis=0)
data_cleaned.shape
# Out:
# (78257, 124)

# %%
Y= data_cleaned['RainTomorrow']
X = data_cleaned.drop('RainTomorrow', axis= 1)
X_train, X_test, y_train, y_test = model_selection.train_test_split(
    X, Y, test_size=0.3, random_state=13)
round( y_test.mean(),2)
# Out:
# 0.23

# %% [markdown]
# Задание 4.7
#
# 1 point possible (graded)
#
# Теперь давайте вспомним про бутстреп. Он не понадобится нам для решения этой задачи, но будет полезно реализовать его «вручную».
#
# Сделайте оценку стандартного отклонения для среднего значения минимальной температуры для обучающей выборки (то есть для среднего значения по признаку MinTemp). Для этого сгенерируйте 1000 случайных выборок из наших данных — каждая из них должна быть такого же объёма, как и обучающая выборка. Для генерации выборки используйте np.random.randint(): сгенерируйте необходимое количество индексов и по ним извлеките соответствующие элементы выборки. Случайность фиксируйте с помощью np.random.seed(31).
#
# Для каждой выборки вычислите среднее значение, а после найдите стандартное отклонение для этих значений. Ответ округлите до двух знаков после точки-разделителя.

# %%
def gbs(data_cleaned, n):     
    inds = np.random.randint(0, len(data_cleaned), (n, len(data_cleaned))) #определяем индексы случайным образом
    numbers = data_cleaned[inds] #выбираем значения по индексам
    return numbers

target = X_train['MinTemp'].values #выбираем целевую переменную
np.random.seed(31) #задаём параметр генератора случайных чисел
#mean_values = [np.mean(X) for X in gbs(target, 1000)] #получаем все средние значения
#np.std(mean_values) #находим для них стандартное отклонение

# %% [markdown]
# Задание 4.8
#
# 1 point possible (graded)
#
# Теперь можно перейти к обучению прогностических моделей. Начнём с того, что построим простейшую логистическую регрессию (без настройки гиперпараметров). Это будет та модель, с качеством которой мы будем сравнивать результаты, полученные далее.
#
# В качестве ответа введите значение метрики roc_auc на тестовой выборке. Ответ округлите до двух знаков после точки-разделителя.

# %%
import pandas as pd
import numpy as np
import sklearn

print(pd.__version__)
print(np.__version__)
print(sklearn.__version__)
# Out:
# 2.2.3
# 1.26.4
# 1.5.2

# %%
dt_4_8 = linear_model.LogisticRegression()
dt_4_8.fit(X_train, y_train)
y_train_pred_4_8 = dt_4_8.predict(X_train)
y_test_pred_4_8 = dt_4_8.predict(X_test)
# Считаем метрику accuracy на тестовой выборке
print('roc_auc_test: {:.2f}'.format(metrics.roc_auc_score(y_test, y_test_pred_4_8)))
#print('roc_auc_train: {:.3f}'.format(metrics.roc_auc(y_train, y_train_pred_4_8)))
# Out:
# roc_auc_test: 0.73
# C:\Users\molde\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# Задание 4.9
#
# 0.0/3.0 points (graded)
#
# Теперь попробуйте обучить на наших данных другой алгоритм — дерево решений. С помощью GridSearchCV сделайте перебор гиперпараметров по следующей сетке:
#
# params = {'max_leaf_nodes': list(range(2, 10)), 'min_samples_split': [2, 3, 4], 'max_depth': [5,7,9,11]}
# Для параметра кросс-валидации cv задайте значение 3. Для решающего дерева определите параметр random_state=42. Остальные параметры оставьте по умолчанию.
#
# 1. Вычислите значение roc_auc для решающего дерева с гиперпараметрами, определёнными в качестве оптимальных. Ответ округлите до двух знаков после точки-разделителя.
#
# 2. Какие значения гиперпараметров были выбраны как оптимальные?

# %%
from sklearn.model_selection import GridSearchCV

# %%
##params = {'max_leaf_nodes': list(range(2, 10)), 'min_samples_split': [2, 3, 4], 'max_depth': [5,7,9,11]}
#GridSearchCV =GridSearchCV(tree.DecisionTreeClassifier(random_state=42),params, verbose=3, cv=3)
#GridSearchCV.fit(X_train,y_train)
#print(GridSearchCV.best_params_)

# %%
model_4_9 = tree.DecisionTreeClassifier(max_depth=5, max_leaf_nodes=9, min_samples_leaf=2,random_state=42)
model_4_9.fit(X_train, y_train)
y_train_pred_4_9 = model_4_9.predict(X_train)
y_test_pred_4_9 = model_4_9.predict(X_test)
print('roc_auc_test: {:.2f}'.format(metrics.roc_auc_score(y_test, y_test_pred_4_9)))
# Out:
# roc_auc_test: 0.71

# %% [markdown]
# Задание 4.10
#
# 1 point possible (graded)
#
# К сожалению, деревья решений не помогли нам в улучшении качества модели, так что попробуем ещё уменьшить ошибку с помощью ансамблей.
#
# Теперь постройте случайный лес, включающий 100 деревьев. Задайте параметр random_state=31. Остальные параметры оставьте по умолчанию.
#
# Какой теперь будет метрика roc_auc на тестовой выборке? Ответ округлите до двух знаков после точки-разделителя.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
#model_4_10 = RandomForestClassifier(n_estimators=100,random_state=31)
#model_4_10.fit(X_train, y_train)
#y_train_pred_4_10 = model_4_10.predict(X_train)
#y_test_pred_4_10 = model_4_10.predict(X_test)
#print('roc_auc_test: {:.2f}'.format(metrics.roc_auc_score(y_test, y_test_pred_4_10)))

# %% [markdown]
# Задание 4.11
#
# 1 point possible (graded)
#
# Основные параметры, которые отвечают за качество обучения в случайном лесе, следующие:'max_features', 'min_samples_leaf', 'max_depth'.
#
# Возьмите случайный лес из 100 деревьев и найдите оптимальную комбинацию этих трёх параметров. Сетка для перебора следующая:
#
# {'max_features': [ 4, 5, 6, 7], 'min_samples_leaf': [3, 5, 7, 9, 11], 'max_depth': [5, 10, 15]}
# Перебор осуществите с помощью GridSearchCV. Для параметра кросс-валидации cv задайте значение 3. Случайности фиксируйте параметром random_state = 31. Остальные значения оставьте по умолчанию.
#
# Какое значение roc_auc получилось для оптимальных гиперпараметров?

# %%
#params = {'max_features': [ 4, 5, 6, 7], 'min_samples_leaf': [3, 5, 7, 9, 11], 'max_depth': [5, 10, 15]}
#GridSearchCV =GridSearchCV(RandomForestClassifier(random_state=42),params, verbose=3, cv=3)
#GridSearchCV.fit(X_train,y_train)
#print(GridSearchCV.best_params_)

# %%
#model_4_11 = RandomForestClassifier(n_estimators = 100, max_depth=15, max_features=7, min_samples_leaf=3, random_state=31)
#model_4_11.fit(X_train, y_train)
#y_train_pred_4_11 = model_4_11.predict(X_train)
#y_test_pred_4_11 = model_4_11.predict(X_test)
#print('roc_auc_test: {:.2f}'.format(metrics.roc_auc_score(y_test, y_test_pred_4_11)))

# %% [markdown]
# Задание 4.12
#
# 0.0/3.0 points (graded)
#
# Как мы говорили в предыдущем юните, благодаря случайному лесу можно узнать, какие признаки оказывают большее влияние на целевую переменную по сравнению с другими.
#
# Оцените значимость признаков. Отметьте три признака, которые дают наибольший вклад в целевую переменную (в каждой колонке находится как минимум один верный вариант ответа):

# %%
#feature_names = [x for x in data_cleaned if x != 'RainTomorrow']
#pd.DataFrame({'feat': feature_names,
              #'coef': model_4_11.feature_importances_}).sort_values(by='coef', ascending=False)

# %% [markdown]
# 6. Бустинг. Практика

# %%
df_air_pass = pd.read_csv('C:\скил\DST-156\IDE_NEW\MATH&ML-9. Математика ансамблевых методов/AirPass.csv')
del df_air_pass['Unnamed: 0']

# %%
df_air_pass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
#  11  Food and drink                     103904 non-null  int64
#  12  Online boarding                    103904 non-null  int64
#  13  Seat comfort                       103904 non-null  int64
#  14  Inflight entertainment             103904 non-null  int64
#  15  On-board service                   103904 non-null  int64
#  16  Leg room service                   103904 non-null  int64
#  17  Baggage handling                   103904 non-null  int64
#  18  Checkin service                    103904 non-null  int64
#  19  Inflight service                   103904 non-null  int64
#  20  Cleanliness                        103904 non-null  int64
#  21  Departure Delay in Minutes         103904 non-null  int64
#  22  Arrival Delay in Minutes           103594 non-null  float64
#  23  satisfaction                       103904 non-null  object
# dtypes: float64(1), int64(18), object(5)
# memory usage: 19.0+ MB

# %% [markdown]
# Задание 6.1
#
# 1 point possible (graded)
#
# Для начала сделаем небольшую предобработку данных. Сколько всего в данных пропущенных значений?

# %%
df_air_pass.isnull().sum().sum()
# Out:
# 310

# %% [markdown]
# Задание 6.2
#
# 1 point possible (graded)
#
# Теперь давайте избавимся от найденных пропусков. Заполните их все медианными значениями. После этого вычислите среднее арифметическое для признака, отражающего задержку при прибытии в минутах. Ответ округлите до двух знаков после точки-разделителя.

# %% [markdown]
# Arrival Delay in Minutes

# %%
df_air_pass['Arrival Delay in Minutes']=df_air_pass['Arrival Delay in Minutes'].fillna(df_air_pass['Arrival Delay in Minutes'].median())

# %%
df_air_pass.isnull().sum().sum()
# Out:
# 0

# %%
round (df_air_pass['Arrival Delay in Minutes'].mean(),2)
# Out:
# 15.13

# %% [markdown]
# Задание 6.3
#
# 3 points possible (graded)
#
# Проведём небольшой разведывательный анализ. Посмотрим, в каких категориях пассажиров превалировали удовлетворённые полетом клиенты.
#
# Совет: для ответов на вопросы попробуйте использовать как вычисления, так и визуализации.

# %% [markdown]
# Satisfaction = satisfaction/neutral/dissatisfaction
#
# Gender

# %%
df_6_3_1=df_air_pass.groupby('Gender')['satisfaction'].value_counts()
df_6_3_1
# Out:
# Gender  satisfaction
# Female  neutral or dissatisfied    30193
#         satisfied                  22534
# Male    neutral or dissatisfied    28686
#         satisfied                  22491
# Name: count, dtype: int64

# %%
df_6_3_2=df_air_pass.groupby('Type of Travel')['satisfaction'].value_counts()
df_6_3_2
# Out:
# Type of Travel   satisfaction
# Business travel  satisfied                  41746
#                  neutral or dissatisfied    29909
# Personal Travel  neutral or dissatisfied    28970
#                  satisfied                   3279
# Name: count, dtype: int64

# %%
df_6_3_3=df_air_pass.groupby('Class')['satisfaction'].value_counts()

#mask_6_3_1=df_6_3_3/df_6_3_3.shape[0]
#mask_6_3_1

df_6_3_3
# Out:
# Class     satisfaction
# Business  satisfied                  34480
#           neutral or dissatisfied    15185
# Eco       neutral or dissatisfied    38044
#           satisfied                   8701
# Eco Plus  neutral or dissatisfied     5650
#           satisfied                   1844
# Name: count, dtype: int64

# %%
df_air_pass['satisfaction'] = df_air_pass['satisfaction'].map({'neutral or dissatisfied':0 , 'satisfied':1})
df_air_pass['Customer Type'] = df_air_pass['Customer Type'].map({'Loyal Customer':1, 'disloyal Customer':0})
df_air_pass['Type of Travel'] = df_air_pass['Type of Travel'].map({'Personal Travel':0, 'Business travel':1})
df_air_pass['Gender'] = df_air_pass['Gender'].map({'Male': 0, 'Female': 1})

# %% [markdown]
# Задание 6.4
#
# 1 point possible (graded)
#
# Для остальных категориальных признаков создайте dummy-переменные. Сделайте это с помощью функции get_dummies() из библиотеки Pandas, параметры не меняйте. Сколько теперь признаков в данных (включая целевую переменную)?

# %%
df_air_pass.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  int64
#  2   Customer Type                      103904 non-null  int64
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  int64
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
#  11  Food and drink                     103904 non-null  int64
#  12  Online boarding                    103904 non-null  int64
#  13  Seat comfort                       103904 non-null  int64
#  14  Inflight entertainment             103904 non-null  int64
#  15  On-board service                   103904 non-null  int64
#  16  Leg room service                   103904 non-null  int64
#  17  Baggage handling                   103904 non-null  int64
#  18  Checkin service                    103904 non-null  int64
#  19  Inflight service                   103904 non-null  int64
#  20  Cleanliness                        103904 non-null  int64
#  21  Departure Delay in Minutes         103904 non-null  int64
#  22  Arrival Delay in Minutes           103904 non-null  float64
#  23  satisfaction                       103904 non-null  int64
# dtypes: float64(1), int64(22), object(1)
# memory usage: 19.0+ MB

# %%
df_air_pass=pd.get_dummies(df_air_pass,columns=['Class'])
df_air_pass
df_air_pass.shape
# Out:
# (103904, 26)

# %% [markdown]
# Задание 6.5
#
# 1 point possible (graded)
#
# Мы практически добрались до обучения модели. Разбейте данные на обучающую и тестовую выборки в соотношении 80/20, параметр random_state = 26. Сколько наблюдений попало в тестовую выборку?

# %%
y= df_air_pass['satisfaction']
X =df_air_pass.drop(['satisfaction'],axis=1)

# Формируем обучающую и тестовую выборки
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2, random_state=26)
print('Train shape: {}'.format(X_train.shape))
print('Test shape: {}'.format(X_test.shape))
# Out:
# Train shape: (83123, 25)
# Test shape: (20781, 25)

# %% [markdown]
# Задание 6.6
#
# 1 point possible (graded)
#
# Теперь нам необходимо реализовать масштабирование данных. Для этого обучите на обучающей выборке метод StandardScaler() и с помощью него преобразуйте и обучающую, и тестовую выборки. Не забудьте, что целевую переменную обрабатывать не нужно.
#
# Примечание. Отметим, что если бы дальше мы работали только с деревьями, масштабирование бы не требовалось. Однако мы реализуем его, чтобы можно было обучать и другие модели и сравнивать полученные результаты.
#
# В качестве ответа введите самое первое значение из матрицы преобразованных признаков тестовой выборки. Округлите значение до двух знаков после точки-разделителя.

# %%
from sklearn.preprocessing import StandardScaler

# %%
# the scaler object (model)
scaler = StandardScaler()
scaler.fit(X_train) 
X_train = scaler.transform(X_train) 
X_test = scaler.transform(X_test) 
round(X_test[0][0],2)
# Out:
# 0.94

# %% [markdown]
# Задание 6.7
#
# 1 point possible (graded)
#
# Перейдём к обучению моделей. В качестве первой модели возьмём самую простую — логистическую регрессию. Мы делаем это для того, чтобы потом сравнивать с ней полученные результаты: так вы сможете выяснить, насколько ансамбли смогут улучшить точность прогноза.
#
# Обучите логистическую регрессию с параметрами по умолчанию на наших данных. В качестве ответа введите значение метрики f1_score. Ответ округлите до трёх знаков после точки-разделителя.

# %%
from sklearn.linear_model import LogisticRegression

# %%
model_LR=LogisticRegression()
model_LR.fit(X_train, y_train)

# Делаем предсказание
y_train_pred_LR = model_LR.predict(X_train)
y_test_pred_LR = model_LR.predict(X_test)
# Считаем метрику f1 на тестовой выборке
print('F1_test: {:.3f}'.format(metrics.f1_score(y_test, y_test_pred_LR)))
#print('F1_train: {:.3f}'.format(metrics.f1_score(y_train, y_train_pred_LR)))
# Out:
# F1_test: 0.855

# %% [markdown]
# Задание 6.8
#
# 1 point possible (graded)
#
# Теперь перейдём к бустингу. Начнём с обучения первой модели — AdaBoost. В качестве базовой модели для неё возьмите решающее дерево с параметром random_state = 26.
#
# Обучите AdaBoost, зафиксировав random_state со значением 26 и задав темп обучения 0.01. В качестве ответа введите значение метрики f1_score. Ответ округлите до трёх знаков после точки-разделителя.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
model_AdaBoost=AdaBoostClassifier(DecisionTreeClassifier(random_state=26),random_state=26,learning_rate=0.001)
model_AdaBoost.fit(X_train, y_train)

# Делаем предсказание
y_train_pred_AdaBoost = model_AdaBoost.predict(X_train)
y_test_pred_AdaBoost = model_AdaBoost.predict(X_test)
# Считаем метрику f1 на тестовой выборке
print('F1_test: {:.3f}'.format(metrics.f1_score(y_test, y_test_pred_AdaBoost)))
#print('F1_train: {:.3f}'.format(metrics.f1_score(y_train, y_train_pred_AdaBoost)))
# Out:
# C:\Users\molde\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\ensemble\_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# F1_test: 0.940

# %% [markdown]
# Задание 6.9
#
# 1 point possible (graded)
#
# Перейдем к следующему алгоритму — градиентному бустингу.
#
# Будем настраивать количество деревьев и темп обучения, делая перебор по следующей сетке:
#
# params = {"n_estimators":2**np.arange(8), "learning_rate":0.1**np.arange(3)}
# Используйте для поиска оптимальных параметров GridSearchCV, а для ускорения работы алгоритма задайте параметр кросс-валидации, равный 3.
#
# Какое наибольшее значение метрики f1_score получилось? Ответ округлите до трёх знаков после точки-разделителя.
#
# Примечание. Необходимо указать лучший результат в методе GridSearchCV на тренировочных данных.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import make_scorer
from sklearn.metrics import f1_score

# %%
#model_GradientBoosting=GradientBoostingClassifier()
#params = {"n_estimators":2**np.arange(8), "learning_rate":0.1**np.arange(3)}
#GridSearchCV =GridSearchCV(GradientBoostingClassifier(),params, cv=3,verbose=5,scoring= make_scorer(f1_score))
#GridSearchCV.fit(X_train,y_train)
#print(GridSearchCV.best_params_)
#print(GridSearchCV.best_score_)

# %% [markdown]
# Задание 6.10
#
# 1 point possible (graded)
#
#
# Обучите алгоритм XGBoost. Так как он достаточно мощный «из коробки», определите его с параметрами по умолчанию, только задайте random_state = 26. Какое значение метрики f1_score получилось? Ответ округлите до трёх знаков после точки-разделителя.
#
# Подсказка. Для того чтобы обучить алгоритм XGBoost для решения задачи классификации, вам понадобится XGBClassifier из библиотеки xgboost, установленной ранее. Вся дальнейшая последовательность действий (обучение модели, предсказание, оценка качества) идентична другим алгоритмам, например логистической регрессии.

# %%
from xgboost import XGBClassifier

# %%
model_XGBoost=XGBClassifier(random_state=26)
model_XGBoost.fit(X_train, y_train)

# Делаем предсказание
y_train_pred_XGBoost = model_XGBoost.predict(X_train)
y_test_pred_XGBoost = model_XGBoost.predict(X_test)
# Считаем метрику f1 на тестовой выборке
print('F1_test: {:.3f}'.format(metrics.f1_score(y_test, y_test_pred_XGBoost)))
print('F1_train: {:.3f}'.format(metrics.f1_score(y_train, y_train_pred_XGBoost)))
# Out:
# F1_test: 0.957
# F1_train: 0.976

# %% [markdown]
# Задание 6.11
#
# 1 point possible (graded)
#
# Обучите алгоритм CatBoost. Как и XGBoost, будем обучать его с настройками по умолчанию и заданным random_state = 26. Какое значение метрики f1_score получилось? Ответ округлите до трёх знаков после точки-разделителя.
#
# Подсказка. Для того чтобы обучить алгоритм CatBoost, вам понадобится CatBoostClassifier() из библиотеки catboost, установленной ранее. Вся дальнейшая последовательность действий (обучение модели, предсказание, оценка качества) идентична другим алгоритмам, например логистической регрессии.

# %%
#pip install catboost

# %%
from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# %%
model_CatBoost=CatBoostClassifier(random_state=26)
model_CatBoost.fit(X_train, y_train)

# Делаем предсказание
y_train_pred_CatBoost = model_CatBoost.predict(X_train)
y_test_pred_CatBoost = model_CatBoost.predict(X_test)
# Считаем метрику f1 на тестовой выборке
print('F1_test: {:.3f}'.format(metrics.f1_score(y_test, y_test_pred_CatBoost)))
print('F1_train: {:.3f}'.format(metrics.f1_score(y_train, y_train_pred_CatBoost)))
# Out:
# Learning rate set to 0.068023
# 0:	learn: 0.6018151	total: 11.2ms	remaining: 11.2s
# 1:	learn: 0.5020758	total: 21.2ms	remaining: 10.6s
# 2:	learn: 0.4472471	total: 29.8ms	remaining: 9.9s
# 3:	learn: 0.4028689	total: 39.4ms	remaining: 9.81s
# 4:	learn: 0.3674734	total: 48.1ms	remaining: 9.57s
# 5:	learn: 0.3397847	total: 58.4ms	remaining: 9.68s
# 6:	learn: 0.3121211	total: 68ms	remaining: 9.65s
# 7:	learn: 0.2917500	total: 85.1ms	remaining: 10.6s
# 8:	learn: 0.2749040	total: 103ms	remaining: 11.3s
# 9:	learn: 0.2575190	total: 116ms	remaining: 11.5s
# 10:	learn: 0.2473691	total: 127ms	remaining: 11.5s
# 11:	learn: 0.2377533	total: 138ms	remaining: 11.4s
# 12:	learn: 0.2279311	total: 148ms	remaining: 11.3s
# 13:	learn: 0.2212511	total: 158ms	remaining: 11.2s
# 14:	learn: 0.2100357	total: 169ms	remaining: 11.1s
# 15:	learn: 0.2025732	total: 180ms	remaining: 11s
# 16:	learn: 0.1942300	total: 190ms	remaining: 11s
# 17:	learn: 0.1877937	total: 201ms	remaining: 11s
# 18:	learn: 0.1832380	total: 211ms	remaining: 10.9s
# 19:	learn: 0.1797365	total: 221ms	remaining: 10.8s
# 20:	learn: 0.1766269	total: 231ms	remaining: 10.8s
# 117:	learn: 0.1000929	total: 1.23s	remaining: 9.17s
# 118:	learn: 0.0999172	total: 1.24s	remaining: 9.17s
# 119:	learn: 0.0995889	total: 1.25s	remaining: 9.17s
# 120:	learn: 0.0992165	total: 1.26s	remaining: 9.16s
# 121:	learn: 0.0991356	total: 1.27s	remaining: 9.15s
# 122:	learn: 0.0990490	total: 1.28s	remaining: 9.13s
# 123:	learn: 0.0988976	total: 1.29s	remaining: 9.13s
# 124:	learn: 0.0987813	total: 1.3s	remaining: 9.11s
# 125:	learn: 0.0982176	total: 1.31s	remaining: 9.1s
# 126:	learn: 0.0979958	total: 1.32s	remaining: 9.09s
# 127:	learn: 0.0975457	total: 1.33s	remaining: 9.07s
# 128:	learn: 0.0973965	total: 1.34s	remaining: 9.07s
# 129:	learn: 0.0971497	total: 1.35s	remaining: 9.05s
# 130:	learn: 0.0969599	total: 1.36s	remaining: 9.04s
# 131:	learn: 0.0968170	total: 1.37s	remaining: 9.04s
# 132:	learn: 0.0966654	total: 1.39s	remaining: 9.04s
# 133:	learn: 0.0965934	total: 1.4s	remaining: 9.03s
# 134:	learn: 0.0965289	total: 1.41s	remaining: 9.02s
# 135:	learn: 0.0963292	total: 1.42s	remaining: 9.01s
# 136:	learn: 0.0962324	total: 1.43s	remaining: 9s
# 137:	learn: 0.0960270	total: 1.44s	remaining: 8.99s
# 138:	learn: 0.0957716	total: 1.45s	remaining: 8.99s
# 139:	learn: 0.0956517	total: 1.46s	remaining: 8.97s
# 140:	learn: 0.0954565	total: 1.47s	remaining: 8.96s
# 141:	learn: 0.0952810	total: 1.48s	remaining: 8.95s
# 142:	learn: 0.0951754	total: 1.49s	remaining: 8.93s
# 143:	learn: 0.0950736	total: 1.5s	remaining: 8.91s
# 144:	learn: 0.0948308	total: 1.51s	remaining: 8.9s
# 145:	learn: 0.0947879	total: 1.52s	remaining: 8.88s
# 146:	learn: 0.0942155	total: 1.53s	remaining: 8.87s
# 147:	learn: 0.0940961	total: 1.54s	remaining: 8.85s
# 148:	learn: 0.0939182	total: 1.55s	remaining: 8.84s
# 149:	learn: 0.0937727	total: 1.56s	remaining: 8.83s
# 150:	learn: 0.0936794	total: 1.57s	remaining: 8.81s
# 151:	learn: 0.0934161	total: 1.58s	remaining: 8.8s
# 152:	learn: 0.0930804	total: 1.59s	remaining: 8.79s
# 153:	learn: 0.0930079	total: 1.6s	remaining: 8.77s
# 154:	learn: 0.0928106	total: 1.6s	remaining: 8.75s
# 155:	learn: 0.0926320	total: 1.61s	remaining: 8.74s
# 156:	learn: 0.0924431	total: 1.63s	remaining: 8.73s
# 157:	learn: 0.0923595	total: 1.63s	remaining: 8.71s
# 158:	learn: 0.0922554	total: 1.65s	remaining: 8.7s
# 159:	learn: 0.0921874	total: 1.65s	remaining: 8.69s
# 160:	learn: 0.0920776	total: 1.66s	remaining: 8.67s
# 161:	learn: 0.0920000	total: 1.68s	remaining: 8.66s
# 162:	learn: 0.0918987	total: 1.68s	remaining: 8.65s
# 163:	learn: 0.0917727	total: 1.69s	remaining: 8.64s
# 164:	learn: 0.0916433	total: 1.7s	remaining: 8.63s
# 165:	learn: 0.0911486	total: 1.71s	remaining: 8.61s
# 166:	learn: 0.0909947	total: 1.72s	remaining: 8.6s
# 167:	learn: 0.0909358	total: 1.73s	remaining: 8.59s
# 168:	learn: 0.0908311	total: 1.74s	remaining: 8.57s
# 169:	learn: 0.0906577	total: 1.75s	remaining: 8.55s
# 170:	learn: 0.0905658	total: 1.76s	remaining: 8.54s
# 171:	learn: 0.0904869	total: 1.77s	remaining: 8.53s
# 172:	learn: 0.0903171	total: 1.78s	remaining: 8.52s
# 173:	learn: 0.0901361	total: 1.79s	remaining: 8.51s
# 174:	learn: 0.0900046	total: 1.8s	remaining: 8.49s
# 175:	learn: 0.0899255	total: 1.81s	remaining: 8.48s
# 176:	learn: 0.0898379	total: 1.82s	remaining: 8.46s
# 177:	learn: 0.0897781	total: 1.83s	remaining: 8.45s
# 178:	learn: 0.0895871	total: 1.84s	remaining: 8.43s
# 179:	learn: 0.0894744	total: 1.85s	remaining: 8.42s
# 180:	learn: 0.0894224	total: 1.86s	remaining: 8.41s
# 181:	learn: 0.0893369	total: 1.87s	remaining: 8.4s
# 182:	learn: 0.0892388	total: 1.88s	remaining: 8.39s
# 183:	learn: 0.0891403	total: 1.89s	remaining: 8.38s
# 184:	learn: 0.0890758	total: 1.9s	remaining: 8.37s
# 185:	learn: 0.0887365	total: 1.91s	remaining: 8.36s
# 186:	learn: 0.0886925	total: 1.92s	remaining: 8.34s
# 187:	learn: 0.0885184	total: 1.93s	remaining: 8.33s
# 188:	learn: 0.0880643	total: 1.94s	remaining: 8.32s
# 189:	learn: 0.0877916	total: 1.95s	remaining: 8.31s
# 190:	learn: 0.0875652	total: 1.96s	remaining: 8.31s
# 191:	learn: 0.0873675	total: 1.97s	remaining: 8.3s
# 192:	learn: 0.0872981	total: 1.98s	remaining: 8.29s
# 193:	learn: 0.0871525	total: 1.99s	remaining: 8.28s
# 194:	learn: 0.0870339	total: 2.01s	remaining: 8.28s
# 195:	learn: 0.0868101	total: 2.02s	remaining: 8.28s
# 196:	learn: 0.0867377	total: 2.03s	remaining: 8.27s
# 197:	learn: 0.0866166	total: 2.04s	remaining: 8.26s
# 198:	learn: 0.0864927	total: 2.05s	remaining: 8.26s
# 199:	learn: 0.0864061	total: 2.06s	remaining: 8.25s
# 200:	learn: 0.0863154	total: 2.07s	remaining: 8.24s
# 201:	learn: 0.0862565	total: 2.08s	remaining: 8.23s
# 202:	learn: 0.0861893	total: 2.09s	remaining: 8.22s
# 203:	learn: 0.0858519	total: 2.1s	remaining: 8.21s
# 204:	learn: 0.0857502	total: 2.11s	remaining: 8.2s
# 205:	learn: 0.0856750	total: 2.12s	remaining: 8.19s
# 206:	learn: 0.0855698	total: 2.13s	remaining: 8.18s
# 207:	learn: 0.0855253	total: 2.14s	remaining: 8.17s
# 208:	learn: 0.0853861	total: 2.15s	remaining: 8.15s
# 209:	learn: 0.0852943	total: 2.17s	remaining: 8.14s
# 725:	learn: 0.0640895	total: 8.57s	remaining: 3.23s
# 726:	learn: 0.0640688	total: 8.58s	remaining: 3.22s
# 727:	learn: 0.0640414	total: 8.6s	remaining: 3.21s
# 728:	learn: 0.0640103	total: 8.62s	remaining: 3.2s
# 729:	learn: 0.0638937	total: 8.64s	remaining: 3.19s
# 730:	learn: 0.0638640	total: 8.65s	remaining: 3.18s
# 731:	learn: 0.0638347	total: 8.67s	remaining: 3.17s
# 732:	learn: 0.0637933	total: 8.69s	remaining: 3.17s
# 733:	learn: 0.0637609	total: 8.71s	remaining: 3.15s
# 734:	learn: 0.0637476	total: 8.72s	remaining: 3.15s
# 735:	learn: 0.0637299	total: 8.74s	remaining: 3.13s
# 736:	learn: 0.0636911	total: 8.76s	remaining: 3.12s
# 737:	learn: 0.0636765	total: 8.77s	remaining: 3.11s
# 738:	learn: 0.0636268	total: 8.79s	remaining: 3.1s
# 739:	learn: 0.0636068	total: 8.8s	remaining: 3.09s
# 740:	learn: 0.0635806	total: 8.82s	remaining: 3.08s
# 741:	learn: 0.0635597	total: 8.84s	remaining: 3.07s
# 742:	learn: 0.0635292	total: 8.85s	remaining: 3.06s
# 743:	learn: 0.0635238	total: 8.87s	remaining: 3.05s
# 744:	learn: 0.0635005	total: 8.88s	remaining: 3.04s
# 745:	learn: 0.0634760	total: 8.9s	remaining: 3.03s
# 746:	learn: 0.0634239	total: 8.92s	remaining: 3.02s
# 747:	learn: 0.0633809	total: 8.93s	remaining: 3.01s
# 748:	learn: 0.0633752	total: 8.95s	remaining: 3s
# 749:	learn: 0.0633550	total: 8.98s	remaining: 2.99s
# 750:	learn: 0.0633090	total: 9s	remaining: 2.98s
# 751:	learn: 0.0633065	total: 9.02s	remaining: 2.98s
# 752:	learn: 0.0632852	total: 9.04s	remaining: 2.96s
# 753:	learn: 0.0632569	total: 9.06s	remaining: 2.96s
# 754:	learn: 0.0632435	total: 9.08s	remaining: 2.94s
# 755:	learn: 0.0632002	total: 9.1s	remaining: 2.94s
# 756:	learn: 0.0631824	total: 9.11s	remaining: 2.92s
# 757:	learn: 0.0631557	total: 9.13s	remaining: 2.92s
# 758:	learn: 0.0631369	total: 9.15s	remaining: 2.9s
# 759:	learn: 0.0631092	total: 9.17s	remaining: 2.9s
# 760:	learn: 0.0630909	total: 9.19s	remaining: 2.88s
# 761:	learn: 0.0630479	total: 9.2s	remaining: 2.88s
# 762:	learn: 0.0630039	total: 9.22s	remaining: 2.86s
# 763:	learn: 0.0629793	total: 9.24s	remaining: 2.85s
# 764:	learn: 0.0629488	total: 9.26s	remaining: 2.84s
# 765:	learn: 0.0629077	total: 9.27s	remaining: 2.83s
# 766:	learn: 0.0628765	total: 9.29s	remaining: 2.82s
# 767:	learn: 0.0628290	total: 9.31s	remaining: 2.81s
# 768:	learn: 0.0627733	total: 9.32s	remaining: 2.8s
# 769:	learn: 0.0627225	total: 9.34s	remaining: 2.79s
# 770:	learn: 0.0627012	total: 9.36s	remaining: 2.78s
# 771:	learn: 0.0626764	total: 9.37s	remaining: 2.77s
# 772:	learn: 0.0626612	total: 9.39s	remaining: 2.76s
# 773:	learn: 0.0626404	total: 9.4s	remaining: 2.75s
# 774:	learn: 0.0626346	total: 9.42s	remaining: 2.73s
# 775:	learn: 0.0626082	total: 9.44s	remaining: 2.72s
# 776:	learn: 0.0625721	total: 9.45s	remaining: 2.71s
# 777:	learn: 0.0625600	total: 9.47s	remaining: 2.7s
# 778:	learn: 0.0625255	total: 9.48s	remaining: 2.69s
# 779:	learn: 0.0624977	total: 9.5s	remaining: 2.68s
# 780:	learn: 0.0624785	total: 9.52s	remaining: 2.67s
# 781:	learn: 0.0624560	total: 9.54s	remaining: 2.66s
# 782:	learn: 0.0624271	total: 9.55s	remaining: 2.65s
# 783:	learn: 0.0624047	total: 9.57s	remaining: 2.64s
# 784:	learn: 0.0623804	total: 9.59s	remaining: 2.63s
# 785:	learn: 0.0623751	total: 9.61s	remaining: 2.62s
# 786:	learn: 0.0623610	total: 9.62s	remaining: 2.6s
# 787:	learn: 0.0623320	total: 9.64s	remaining: 2.59s
# 788:	learn: 0.0623035	total: 9.66s	remaining: 2.58s
# 789:	learn: 0.0622877	total: 9.68s	remaining: 2.57s
# 790:	learn: 0.0622084	total: 9.7s	remaining: 2.56s
# 791:	learn: 0.0621729	total: 9.71s	remaining: 2.55s
# 792:	learn: 0.0621158	total: 9.73s	remaining: 2.54s
# 793:	learn: 0.0620814	total: 9.75s	remaining: 2.53s
# 794:	learn: 0.0620559	total: 9.77s	remaining: 2.52s
# 795:	learn: 0.0620189	total: 9.79s	remaining: 2.51s
# 796:	learn: 0.0619890	total: 9.8s	remaining: 2.5s
# 797:	learn: 0.0619611	total: 9.82s	remaining: 2.49s
# 798:	learn: 0.0619489	total: 9.84s	remaining: 2.48s
# 799:	learn: 0.0619473	total: 9.86s	remaining: 2.46s
# 800:	learn: 0.0619157	total: 9.87s	remaining: 2.45s
# 801:	learn: 0.0618949	total: 9.89s	remaining: 2.44s
# 802:	learn: 0.0618697	total: 9.91s	remaining: 2.43s
# 803:	learn: 0.0618486	total: 9.93s	remaining: 2.42s
# 804:	learn: 0.0618263	total: 9.95s	remaining: 2.41s
# 805:	learn: 0.0617944	total: 9.97s	remaining: 2.4s
# 806:	learn: 0.0617727	total: 9.98s	remaining: 2.39s
# 807:	learn: 0.0617473	total: 10s	remaining: 2.38s
# 808:	learn: 0.0617352	total: 10s	remaining: 2.37s
# 809:	learn: 0.0617030	total: 10s	remaining: 2.35s
# 810:	learn: 0.0616899	total: 10s	remaining: 2.34s
# 811:	learn: 0.0616773	total: 10.1s	remaining: 2.33s
# 812:	learn: 0.0616557	total: 10.1s	remaining: 2.32s
# 813:	learn: 0.0616250	total: 10.1s	remaining: 2.31s
# 814:	learn: 0.0616133	total: 10.1s	remaining: 2.29s
# 815:	learn: 0.0615647	total: 10.1s	remaining: 2.28s
# 816:	learn: 0.0615062	total: 10.2s	remaining: 2.27s
# 817:	learn: 0.0614629	total: 10.2s	remaining: 2.26s
# 818:	learn: 0.0614367	total: 10.2s	remaining: 2.25s
# 819:	learn: 0.0614150	total: 10.2s	remaining: 2.24s
# 820:	learn: 0.0613916	total: 10.2s	remaining: 2.23s
# 821:	learn: 0.0613703	total: 10.2s	remaining: 2.21s
# 822:	learn: 0.0613531	total: 10.2s	remaining: 2.2s
# 823:	learn: 0.0613115	total: 10.3s	remaining: 2.19s
# 824:	learn: 0.0612821	total: 10.3s	remaining: 2.18s
# 825:	learn: 0.0612744	total: 10.3s	remaining: 2.17s
# 826:	learn: 0.0612289	total: 10.3s	remaining: 2.16s
# 827:	learn: 0.0612275	total: 10.3s	remaining: 2.15s
# 828:	learn: 0.0612131	total: 10.3s	remaining: 2.13s
# 829:	learn: 0.0611871	total: 10.4s	remaining: 2.12s
# 830:	learn: 0.0611644	total: 10.4s	remaining: 2.11s
# 831:	learn: 0.0611542	total: 10.4s	remaining: 2.1s
# 832:	learn: 0.0611259	total: 10.4s	remaining: 2.09s
# 833:	learn: 0.0611038	total: 10.4s	remaining: 2.08s
# 834:	learn: 0.0610672	total: 10.4s	remaining: 2.06s
# 835:	learn: 0.0610409	total: 10.5s	remaining: 2.05s
# 836:	learn: 0.0610036	total: 10.5s	remaining: 2.04s
# 837:	learn: 0.0610016	total: 10.5s	remaining: 2.03s
# 838:	learn: 0.0609715	total: 10.5s	remaining: 2.02s
# 839:	learn: 0.0609365	total: 10.5s	remaining: 2s
# 840:	learn: 0.0609257	total: 10.5s	remaining: 1.99s
# 841:	learn: 0.0608953	total: 10.6s	remaining: 1.98s
# 842:	learn: 0.0608625	total: 10.6s	remaining: 1.97s
# 843:	learn: 0.0608462	total: 10.6s	remaining: 1.96s
# 844:	learn: 0.0608251	total: 10.6s	remaining: 1.95s
# 845:	learn: 0.0608029	total: 10.6s	remaining: 1.93s
# 846:	learn: 0.0607847	total: 10.6s	remaining: 1.92s
# 847:	learn: 0.0607694	total: 10.7s	remaining: 1.91s
# 848:	learn: 0.0607487	total: 10.7s	remaining: 1.9s
# 849:	learn: 0.0607301	total: 10.7s	remaining: 1.89s
# 850:	learn: 0.0607188	total: 10.7s	remaining: 1.88s
# 851:	learn: 0.0606925	total: 10.7s	remaining: 1.86s
# 852:	learn: 0.0606714	total: 10.7s	remaining: 1.85s
# 853:	learn: 0.0606504	total: 10.8s	remaining: 1.84s
# 854:	learn: 0.0606235	total: 10.8s	remaining: 1.83s
# 855:	learn: 0.0606004	total: 10.8s	remaining: 1.82s
# 856:	learn: 0.0605626	total: 10.8s	remaining: 1.8s
# 857:	learn: 0.0605188	total: 10.8s	remaining: 1.79s
# 858:	learn: 0.0605003	total: 10.8s	remaining: 1.78s
# 859:	learn: 0.0604774	total: 10.9s	remaining: 1.77s
# 860:	learn: 0.0604586	total: 10.9s	remaining: 1.75s
# 861:	learn: 0.0604364	total: 10.9s	remaining: 1.74s
# 862:	learn: 0.0604252	total: 10.9s	remaining: 1.73s
# 863:	learn: 0.0604026	total: 10.9s	remaining: 1.72s
# 864:	learn: 0.0603883	total: 10.9s	remaining: 1.71s
# 865:	learn: 0.0603471	total: 11s	remaining: 1.7s
# 866:	learn: 0.0603293	total: 11s	remaining: 1.68s
# 867:	learn: 0.0603074	total: 11s	remaining: 1.67s
# 868:	learn: 0.0602843	total: 11s	remaining: 1.66s
# 869:	learn: 0.0602578	total: 11s	remaining: 1.65s
# 870:	learn: 0.0602165	total: 11.1s	remaining: 1.64s
# 871:	learn: 0.0601863	total: 11.1s	remaining: 1.63s
# 872:	learn: 0.0601760	total: 11.1s	remaining: 1.61s
# 873:	learn: 0.0601622	total: 11.1s	remaining: 1.6s
# 874:	learn: 0.0601376	total: 11.1s	remaining: 1.59s
# 875:	learn: 0.0601009	total: 11.1s	remaining: 1.58s
# 876:	learn: 0.0600825	total: 11.2s	remaining: 1.56s
# 877:	learn: 0.0600720	total: 11.2s	remaining: 1.55s
# 878:	learn: 0.0600623	total: 11.2s	remaining: 1.54s
# 879:	learn: 0.0600379	total: 11.2s	remaining: 1.53s
# 880:	learn: 0.0600292	total: 11.2s	remaining: 1.52s
# 881:	learn: 0.0600116	total: 11.2s	remaining: 1.5s
# 882:	learn: 0.0600008	total: 11.3s	remaining: 1.49s
# 883:	learn: 0.0599802	total: 11.3s	remaining: 1.48s
# 884:	learn: 0.0599631	total: 11.3s	remaining: 1.47s
# 885:	learn: 0.0599321	total: 11.3s	remaining: 1.46s
# 886:	learn: 0.0599306	total: 11.3s	remaining: 1.44s
# 887:	learn: 0.0599190	total: 11.3s	remaining: 1.43s
# 888:	learn: 0.0599008	total: 11.4s	remaining: 1.42s
# 889:	learn: 0.0598852	total: 11.4s	remaining: 1.41s
# 890:	learn: 0.0598694	total: 11.4s	remaining: 1.39s
# 891:	learn: 0.0598307	total: 11.4s	remaining: 1.38s
# 892:	learn: 0.0598054	total: 11.4s	remaining: 1.37s
# 893:	learn: 0.0597837	total: 11.4s	remaining: 1.36s
# 894:	learn: 0.0597723	total: 11.5s	remaining: 1.34s
# 895:	learn: 0.0597468	total: 11.5s	remaining: 1.33s
# 896:	learn: 0.0597168	total: 11.5s	remaining: 1.32s
# 897:	learn: 0.0597109	total: 11.5s	remaining: 1.31s
# 898:	learn: 0.0596987	total: 11.5s	remaining: 1.29s
# 899:	learn: 0.0596692	total: 11.5s	remaining: 1.28s
# 900:	learn: 0.0596499	total: 11.6s	remaining: 1.27s
# 901:	learn: 0.0596142	total: 11.6s	remaining: 1.26s
# 902:	learn: 0.0595867	total: 11.6s	remaining: 1.24s
# 903:	learn: 0.0595867	total: 11.6s	remaining: 1.23s
# 904:	learn: 0.0595628	total: 11.6s	remaining: 1.22s
# 905:	learn: 0.0595428	total: 11.6s	remaining: 1.21s
# 906:	learn: 0.0595111	total: 11.7s	remaining: 1.2s
# 907:	learn: 0.0594730	total: 11.7s	remaining: 1.18s
# 908:	learn: 0.0594557	total: 11.7s	remaining: 1.17s
# 909:	learn: 0.0594356	total: 11.7s	remaining: 1.16s
# 910:	learn: 0.0594209	total: 11.7s	remaining: 1.15s
# 911:	learn: 0.0593883	total: 11.7s	remaining: 1.13s
# 961:	learn: 0.0582467	total: 12.6s	remaining: 498ms
# 962:	learn: 0.0582206	total: 12.6s	remaining: 485ms
# 963:	learn: 0.0582031	total: 12.6s	remaining: 472ms
# 964:	learn: 0.0581714	total: 12.7s	remaining: 459ms
# 965:	learn: 0.0581501	total: 12.7s	remaining: 446ms
# 966:	learn: 0.0581261	total: 12.7s	remaining: 433ms
# 967:	learn: 0.0580959	total: 12.7s	remaining: 420ms
# 968:	learn: 0.0580611	total: 12.7s	remaining: 407ms
# 969:	learn: 0.0580390	total: 12.7s	remaining: 394ms
# 970:	learn: 0.0580242	total: 12.8s	remaining: 381ms
# 971:	learn: 0.0579858	total: 12.8s	remaining: 368ms
# 972:	learn: 0.0579701	total: 12.8s	remaining: 355ms
# 973:	learn: 0.0579389	total: 12.8s	remaining: 342ms
# 974:	learn: 0.0578729	total: 12.8s	remaining: 329ms
# 975:	learn: 0.0578442	total: 12.9s	remaining: 316ms
# 976:	learn: 0.0578203	total: 12.9s	remaining: 303ms
# 977:	learn: 0.0578186	total: 12.9s	remaining: 290ms
# 978:	learn: 0.0577990	total: 12.9s	remaining: 277ms
# 979:	learn: 0.0577769	total: 12.9s	remaining: 264ms
# 980:	learn: 0.0577534	total: 12.9s	remaining: 251ms
# 981:	learn: 0.0577211	total: 13s	remaining: 237ms
# 982:	learn: 0.0577075	total: 13s	remaining: 224ms
# 983:	learn: 0.0576919	total: 13s	remaining: 211ms
# 984:	learn: 0.0576694	total: 13s	remaining: 198ms
# 985:	learn: 0.0576572	total: 13s	remaining: 185ms
# 986:	learn: 0.0576344	total: 13s	remaining: 172ms
# 987:	learn: 0.0576051	total: 13.1s	remaining: 159ms
# 988:	learn: 0.0575898	total: 13.1s	remaining: 145ms
# 989:	learn: 0.0575816	total: 13.1s	remaining: 132ms
# 990:	learn: 0.0575727	total: 13.1s	remaining: 119ms
# 991:	learn: 0.0575660	total: 13.1s	remaining: 106ms
# 992:	learn: 0.0575488	total: 13.1s	remaining: 92.6ms
# 993:	learn: 0.0575447	total: 13.1s	remaining: 79.4ms
# 994:	learn: 0.0575398	total: 13.2s	remaining: 66.1ms
# 995:	learn: 0.0575253	total: 13.2s	remaining: 52.9ms
# 996:	learn: 0.0575023	total: 13.2s	remaining: 39.7ms
# 997:	learn: 0.0574980	total: 13.2s	remaining: 26.5ms
# 998:	learn: 0.0574763	total: 13.2s	remaining: 13.2ms
# 999:	learn: 0.0574650	total: 13.2s	remaining: 0us
# F1_test: 0.960
# F1_train: 0.974

# %% [markdown]
# Задание 6.12
#
# 4 points possible (graded)
#
# Выведите матрицу ошибок для алгоритма, который получил наилучшие показатели качества модели на обучающей выборке (будем считать, что оцениваем по f1_score). Матрица ошибок выводится в следующем формате:

# %%
from catboost.utils import get_confusion_matrix
from catboost import Pool

# %%
d_6_12=get_confusion_matrix(model_CatBoost, Pool(X_train, y_train))
d_6_12
(d_6_12 / d_6_12.sum())*100
# Out:
# array([[56.11804194,  0.67249738],
#        [ 1.53146542, 41.67799526]])

# %% [markdown]
# Задание 6.13
#
# 1 point possible (graded)
#
# Оцените важность признаков для модели из предыдущего задания. Отметьте признак, который оказывает наибольшее влияние на значение целевой переменной:

# %%
feature_names = [x for x in df_air_pass if x != 'satisfaction']
pd.DataFrame({'feat': feature_names,
              'coef': model_CatBoost.feature_importances_}).sort_values(by='coef', ascending=False)
# Out:
#                                  feat       coef
# 6               Inflight wifi service  26.001691
# 4                      Type of Travel  17.854438
# 11                    Online boarding   7.582693
# 2                       Customer Type   7.291082
# 22                     Class_Business   5.334009
# 17                    Checkin service   3.935882
# 16                   Baggage handling   3.675108
# 3                                 Age   3.653960
# 9                       Gate location   3.537978
# 18                   Inflight service   2.840194
# 12                       Seat comfort   2.804871
# 13             Inflight entertainment   2.804743
# 0                                  id   1.998636
# 5                     Flight Distance   1.688033
# 19                        Cleanliness   1.514438
# 8              Ease of Online booking   1.458928
# 14                   On-board service   1.443881
# 7   Departure/Arrival time convenient   1.430287
# 15                   Leg room service   1.157490
# 21           Arrival Delay in Minutes   0.846765
# 20         Departure Delay in Minutes   0.445596
# 10                     Food and drink   0.356811
# 24                     Class_Eco Plus   0.167712
# 23                          Class_Eco   0.124950
# 1                              Gender   0.049823

# %% [markdown]
# 7. Стекинг

# %% [markdown]
# Frogs_MFCCs

# %%
df_7 = pd.read_csv('C:\скил\DST-156\IDE_NEW\MATH&ML-9. Математика ансамблевых методов/Frogs_MFCCs.csv')
df_7.head()
# Out:
#    MFCCs_ 1  MFCCs_ 2  MFCCs_ 3  MFCCs_ 4  MFCCs_ 5  MFCCs_ 6  MFCCs_ 7  \
# 0       1.0  0.152936 -0.105586  0.200722  0.317201  0.260764  0.100945
# 1       1.0  0.171534 -0.098975  0.268425  0.338672  0.268353  0.060835
# 2       1.0  0.152317 -0.082973  0.287128  0.276014  0.189867  0.008714
# 3       1.0  0.224392  0.118985  0.329432  0.372088  0.361005  0.015501
# 4       1.0  0.087817 -0.068345  0.306967  0.330923  0.249144  0.006884
#
#    MFCCs_ 8  MFCCs_ 9  MFCCs_10  ...  MFCCs_17  MFCCs_18  MFCCs_19  MFCCs_20  \
# 0 -0.150063 -0.171128  0.124676  ... -0.108351 -0.077623 -0.009568  0.057684
# 1 -0.222475 -0.207693  0.170883  ... -0.090974 -0.056510 -0.035303  0.020140
# 2 -0.242234 -0.219153  0.232538  ... -0.050691 -0.023590 -0.066722 -0.025083
# 3 -0.194347 -0.098181  0.270375  ... -0.136009 -0.177037 -0.130498 -0.054766
# 4 -0.265423 -0.172700  0.266434  ... -0.048885 -0.053074 -0.088550 -0.031346
#
#    MFCCs_21  MFCCs_22           Family      Genus         Species  RecordID
# 0  0.118680  0.014038  Leptodactylidae  Adenomera  AdenomeraAndre         1
# 1  0.082263  0.029056  Leptodactylidae  Adenomera  AdenomeraAndre         1
# 2  0.099108  0.077162  Leptodactylidae  Adenomera  AdenomeraAndre         1
# 3 -0.018691  0.023954  Leptodactylidae  Adenomera  AdenomeraAndre         1
# 4  0.108610  0.079244  Leptodactylidae  Adenomera  AdenomeraAndre         1
#
# [5 rows x 26 columns]

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7195 entries, 0 to 7194
# Data columns (total 26 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MFCCs_ 1  7195 non-null   float64
#  1   MFCCs_ 2  7195 non-null   float64
#  2   MFCCs_ 3  7195 non-null   float64
#  3   MFCCs_ 4  7195 non-null   float64
#  4   MFCCs_ 5  7195 non-null   float64
#  5   MFCCs_ 6  7195 non-null   float64
#  6   MFCCs_ 7  7195 non-null   float64
#  7   MFCCs_ 8  7195 non-null   float64
#  8   MFCCs_ 9  7195 non-null   float64
#  9   MFCCs_10  7195 non-null   float64
#  10  MFCCs_11  7195 non-null   float64
#  11  MFCCs_12  7195 non-null   float64
#  12  MFCCs_13  7195 non-null   float64
#  13  MFCCs_14  7195 non-null   float64
#  14  MFCCs_15  7195 non-null   float64
#  15  MFCCs_16  7195 non-null   float64
#  16  MFCCs_17  7195 non-null   float64
#  17  MFCCs_18  7195 non-null   float64
#  18  MFCCs_19  7195 non-null   float64
#  19  MFCCs_20  7195 non-null   float64
#  20  MFCCs_21  7195 non-null   float64
#  21  MFCCs_22  7195 non-null   float64
#  22  Family    7195 non-null   object
#  23  Genus     7195 non-null   object
#  24  Species   7195 non-null   object
#  25  RecordID  7195 non-null   int64
# dtypes: float64(22), int64(1), object(3)
# memory usage: 1.4+ MB

# %%
df_7=df_7.drop(['Genus','Species','RecordID'],axis=1)

# %%
df_7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7195 entries, 0 to 7194
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   MFCCs_ 1  7195 non-null   float64
#  1   MFCCs_ 2  7195 non-null   float64
#  2   MFCCs_ 3  7195 non-null   float64
#  3   MFCCs_ 4  7195 non-null   float64
#  4   MFCCs_ 5  7195 non-null   float64
#  5   MFCCs_ 6  7195 non-null   float64
#  6   MFCCs_ 7  7195 non-null   float64
#  7   MFCCs_ 8  7195 non-null   float64
#  8   MFCCs_ 9  7195 non-null   float64
#  9   MFCCs_10  7195 non-null   float64
#  10  MFCCs_11  7195 non-null   float64
#  11  MFCCs_12  7195 non-null   float64
#  12  MFCCs_13  7195 non-null   float64
#  13  MFCCs_14  7195 non-null   float64
#  14  MFCCs_15  7195 non-null   float64
#  15  MFCCs_16  7195 non-null   float64
#  16  MFCCs_17  7195 non-null   float64
#  17  MFCCs_18  7195 non-null   float64
#  18  MFCCs_19  7195 non-null   float64
#  19  MFCCs_20  7195 non-null   float64
#  20  MFCCs_21  7195 non-null   float64
#  21  MFCCs_22  7195 non-null   float64
#  22  Family    7195 non-null   object
# dtypes: float64(22), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# Задание 7.5
#
# 1/1 point (graded)
#
# Для начала обучите на наших данных случайный лес с десятью решающими деревьями. Воспользуйтесь параметрами по умолчанию. В качестве значения random_state возьмите число 42.
#
# Оцените значение -меры и введите его в качестве ответа, предварительно округлив до двух знаков после точки-разделителя.

# %%
y= df_7['Family']
X =df_7.drop(['Family'],axis=1)

# Формируем обучающую и тестовую выборки
X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.2, stratify=y, random_state=31)
#print('Train shape: {}'.format(X_train.shape))
#print('Test shape: {}'.format(X_test.shape))

# %%
#y.unique()
# Out:
# array(['Leptodactylidae', 'Dendrobatidae', 'Hylidae', 'Bufonidae'],
#       dtype=object)

# %%
#model_rfc = RandomForestClassifier(10, random_state=42)
#model_rfc.fit(X_train, y_train)
#pred = model_rfc.predict(X_test)
#f1_score(y_test, pred)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[292], line 4
#       2 model_rfc.fit(X_train, y_train)
#       3 pred = model_rfc.predict(X_test)
# ----> 4 f1_score(y_test, pred)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:213, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     207 try:
#     208     with config_context(
#     209         skip_parameter_validation=(
#     210             prefer_skip_nested_validation or global_skip_validation
#     211         )
#     212     ):
# --> 213         return func(*args, **kwargs)
#     214 except InvalidParameterError as e:
#     215     # When the function is just a wrapper around an estimator, we allow
#     216     # the function to delegate validation to the estimator, but we replace
#     217     # the name of the estimator by the name of the function in the error
#     218     # message to avoid confusion.
#     219     msg = re.sub(
#     220         r"parameter of \w+ must be",
#     221         f"parameter of {func.__qualname__} must be",
#     222         str(e),
#     223     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1293, in f1_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1113 @validate_params(
#    1114     {
#    1115         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1140     zero_division="warn",
#    1141 ):
#    1142     """Compute the F1 score, also known as balanced F-score or F-measure.
#    1143
#    1144     The F1 score can be interpreted as a harmonic mean of the precision and
#    (...)
#    1291     array([0.66666667, 1.        , 0.66666667])
#    1292     """
# -> 1293     return fbeta_score(
#    1294         y_true,
#    1295         y_pred,
#    1296         beta=1,
#    1297         labels=labels,
#    1298         pos_label=pos_label,
#    1299         average=average,
#    1300         sample_weight=sample_weight,
#    1301         zero_division=zero_division,
#    1302     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1485, in fbeta_score(y_true, y_pred, beta, labels, pos_label, average, sample_weight, zero_division)
#    1305 @validate_params(
#    1306     {
#    1307         "y_true": ["array-like", "sparse matrix"],
#    (...)
#    1334     zero_division="warn",
#    1335 ):
#    1336     """Compute the F-beta score.
#    1337
#    1338     The F-beta score is the weighted harmonic mean of precision and recall,
#    (...)
#    1482     np.float64(0.12...)
#    1483     """
# -> 1485     _, _, f, _ = precision_recall_fscore_support(
#    1486         y_true,
#    1487         y_pred,
#    1488         beta=beta,
#    1489         labels=labels,
#    1490         pos_label=pos_label,
#    1491         average=average,
#    1492         warn_for=("f-score",),
#    1493         sample_weight=sample_weight,
#    1494         zero_division=zero_division,
#    1495     )
#    1496     return f
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:186, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     184 global_skip_validation = get_config()["skip_parameter_validation"]
#     185 if global_skip_validation:
# --> 186     return func(*args, **kwargs)
#     188 func_sig = signature(func)
#     190 # Map *args/**kwargs to the function signature
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1789, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1626 """Compute precision, recall, F-measure and support for each class.
#    1627
#    1628 The precision is the ratio ``tp / (tp + fp)`` where ``tp`` is the number of
#    (...)
#    1786  array([2, 2, 2]))
#    1787 """
#    1788 _check_zero_division(zero_division)
# -> 1789 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1791 # Calculate tp_sum, pred_sum, true_sum ###
#    1792 samplewise = average == "samples"
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1578, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1576         if y_type == "multiclass":
#    1577             average_options.remove("samples")
# -> 1578         raise ValueError(
#    1579             "Target is %s but average='binary'. Please "
#    1580             "choose another average setting, one of %r." % (y_type, average_options)
#    1581         )
#    1582 elif pos_label not in (None, 1):
#    1583     warnings.warn(
#    1584         "Note that pos_label (set to %r) is ignored when "
#    1585         "average != 'binary' (got %r). You may use "
#    (...)
#    1588         UserWarning,
#    1589     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
model_7_7_5 = RandomForestClassifier(n_estimators = 10, random_state=42)
model_7_7_5.fit(X_train, y_train)
y_train_pred_7_7_5 = model_7_7_5.predict(X_train)
y_test_pred_7_7_5 = model_7_7_5.predict(X_test)

print('F1_test: {:.4f}'.format(metrics.f1_score(y_test, y_test_pred_7_7_5,average='macro')))
print('F1_train: {:.4f}'.format(metrics.f1_score(y_train, y_train_pred_7_7_5,average='macro')))
# Out:
# F1_test: 0.9645
# F1_train: 0.9972

# %% [markdown]
# Задание 7.6
#
# 1 point possible (graded)
#
# Теперь попробуем улучшить качество нашего предсказания за счёт использования стекинга.
#
# В качестве базовых моделей выберите следующие:
#
# случайный лес с десятью деревьями, random_state = 31;
# KNN, количество соседей = 11;
# наивный байесовский классификатор с параметрами по умолчанию, в качестве метода возьмите GaussianNB().
# В качестве метамодели выберите логистическую регрессию.
#
# Обучите модели и сделайте предсказание целевой метки для тестового набора данных.
#
# Рассчитайте -меру для тестового набора данных и введите её в качестве ответа, предварительно округлив до двух знаков после точки-разделителя.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import StackingClassifier

# %%
estimators = [('rf', RandomForestClassifier(n_estimators=10, random_state=31)),
              ('knn', KNeighborsClassifier(n_neighbors= 11)),
              ('nb', GaussianNB() )               
]
metamodel = StackingClassifier(
    estimators=estimators, final_estimator=LogisticRegression()
)
metamodel.fit(X_train, y_train)
pred = metamodel.predict(X_test)
f1_score(y_test, pred,average='macro')
# Out:
# 0.9900446463372055
