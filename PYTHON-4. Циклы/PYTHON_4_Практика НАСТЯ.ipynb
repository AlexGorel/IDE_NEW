# %% [markdown]
# Пример задания:
# Ваша задача - разработать программу на языке Python, анализирующую текстовые данные.
# Выберите текст, который вам интересен - это может быть:
# литературное произведение (например, рассказ, стихотворение, отрывок из романа);
# тексты песен;
# статьи или посты из открытых источников.
# Программа должна считать данные из текстового файла (например, text_word_word.txt), выполнить их базовую обработку и вывести результаты анализа.
# Пример того, что может делать программа:
# посчитать общее количество слов и предложений;
# определить 10 самых частотных слов (исключая предлоги, союзы и местоимения);
# посчитать, сколько раз встречается выбранное пользователем слово;
# вычислить среднюю длину слова и предложения;
# посчитать, сколько слов начинается с каждой буквы алфавита;
# вывести "облако слов" (в виде текстового списка, без графиков).
# Результаты должны быть выведены на экран и записаны в файл results.txt.

# %% [markdown]
# Критерии
#
#
# Использование библиотек / импортированных функций	Использовано более одной библиотеки	Использовано более одной внешней библиотеки или импортированной функции.	-2      НЕ ИСПОЛЬЗОВАНО
#
# Использована одна библиотека	Использована одна библиотека / импортированная функция.	-1   НЕ ИСПОЛЬЗОВАНО
#
# Без библиотек	Не использованы внешние библиотеки / импортированные функции.	0    НЕ ИСПОЛЬЗОВАНО
#
# Исходные данные	Нет файла данных	Файл с входными данными для анализа отсутствует или не читается.	0
# ![image.png](attachment:image.png)
# Менее 50 строк текста	Файл содержит менее 50 строк текста.	0.5
#
# Не менее 100 строк текста	Файл содержит не менее 100 строк текста.	1     157 СТРОК ВСТРОЕН В КОД (+ ЕСТЬ ВОЗМОЖНОСТЬ СКАЧАТЬ С ФАЙЛООБМЕННИКА)
#
#
# Работа с файлами	Ошибка при чтении или записи	Файл не читается или результат не сохраняется.	0
#
# Чтение/запись частично корректны	Файл читается и записывается, но с ошибками или неполными данными.	0.5
#
# Корректная работа с файлами	Программа корректно считывает данные из файла и сохраняет результаты в results.txt.	1
#
# Текстовые характеристики	Менее 3 характеристик	Подсчитано менее трёх текстовых характеристик (например, только количество слов и предложений).	0.25
# 3–4 характеристики	Подсчитано 3–4 текстовые характеристики.	0.5
# 5 и более характеристик	Подсчитано не менее 5 текстовых характеристик (например: количество слов, средняя длина слова, топ слов, частота заданного слова и т.д.).	1
# Условные конструкции	Отсутствуют	В коде нет условных конструкций.	0
# С ошибками	Условные конструкции используются с ошибками или не по назначению.	0.5
# Корректные	Используются условные конструкции if, elif, else без ошибок.	1
# Циклы	Отсутствуют циклы	Не используются циклы для обработки текста.	0
# Циклы с ошибками	Циклы for или while используются с ошибками.	0.5
# Циклы корректны	Циклы for или while реализованы корректно для обхода слов и предложений.	1
# Структуры данных	Не используются	Списки, множества и словари не применяются.	0
# Используются частично или с ошибками	Структуры данных применяются, но с логическими ошибками.	0.5
# Используются корректно	Списки, множества и словари применяются по назначению для анализа текста.	1
# Функции	Нет функций	Отсутствуют собственные функции.	0
# Функция с ошибками	Есть хотя бы одна функция, но она не выполняет задачу корректно.	0.5
# Корректная функция	Создана хотя бы одна функция, выполняющая логическую часть анализа текста.	1
# Вывод результатов	Нет вывода	Результаты анализа не отображаются.	0
# Частичный вывод	Выведены не все рассчитанные характеристики.	0.5
# Полный вывод	Все рассчитанные показатели отображаются на экране и сохраняются в results.txt.	1
# Избыточный код	Есть лишний код	Присутствуют дублирующиеся или неиспользуемые участки кода.	-2
# Код оптимален	Код написан без избыточных частей.	0
# Комментарии и читаемость кода	Отсутствуют комментарии	В коде отсутствуют поясняющие комментарии (менее 3 строк с #).	0
# Частично прокомментирован код	Есть 3–5 комментариев, поясняющих отдельные шаги.	0.5
# Хорошо документированный код	Код снабжён осмысленными комментариями (≥5), поясняющими логику и функции.	1
# Тематика текста (гуманитарная направленность)	Не соответствует гуманитарной тематике	Текст не имеет отношения к гуманитарным наукам (например, технический мануал, код, таблицы данных).	0
# Частично гуманитарный	Текст частично связан с гуманитарными дисциплинами (литература, культура, история, язык).	0.5
# Полностью гуманитарный	Текст напрямую относится к гуманитарной тематике (литературное произведение, песня, статья о культуре и т.д.).	1

# %%
# Программа для чтения всего файла с использованием функции read()
file = open("C:\скил\DST-156\IDE_NEW\PYTHON-4. Циклы/Text Document.txt", "r")
text = file.read()
file.close()
# Приводим текст к нижнему регистру

# %% [markdown]
# # Программа для чтения всего файла с использованием функции read()
# file = open("C:\скил\DST-156\IDE_NEW\PYTHON-4. Циклы/Text Document.txt", "r")
# text = file.read()
# file.close()
# # Приводим текст к нижнему регистру

# %%
text = """
CHAPTER I
Down the Rabbit-Hole.
Alice was beginning to get very tired of sitting by her sister on the bank, and of having nothing to do: once or twice she had peeped into the book her sister was reading, but it had no pictures or conversations in it, 'and what is the use of a book,' thought Alice 'without pictures or conversation?'
So she was considering in her own mind (as well as she could, for the hot day made her feel very sleepy and stupid), whether the pleasure of making a daisy-chain would be worth the trouble of getting up and picking the daisies, when suddenly a White Rabbit with pink eyes ran close by her.
There was nothing so very remarkable in that; nor did Alice think it so very much out of the way to hear the Rabbit say to itself, 'Oh dear! Oh dear! I shall be late!' (when she thought it over afterwards, it occurred to her that she ought to have wondered at this, but at the time it all seemed quite natural); but when the Rabbit actually took a watch out of its waistcoat-pocket, and looked at it, and then hurried on, Alice started to her feet, for it flashed across her mind that she had never before see a rabbit with either a waistcoat-pocket, or a watch to take out of it, and burning with curiosity, she ran across the field after it, and fortunately was just in time to see it pop down a large rabbit-hole under the hedge.
In another moment down went Alice after it, never once considering how in the world she was to get out again.
The rabbit-hole went straight on like a tunnel for some way, and then dipped suddenly down, so suddenly that Alice had not a moment to think about stopping herself before she found herself falling down a very deep well.
Either the well was very deep, or she fell very slowly, for she had plenty of time as she went down to look about her and to wonder what was going to happen next. First, she tried to look down and make out what she was coming to, but it was too dark to see anything; then she looked at the sides of the well, and noticed that they were filled with cupboards and book-shelves; here and there she saw maps and pictures hung upon pegs. She took down a jar from one of the shelves as she passed; it was labelled 'ORANGE MARMALADE', but to her great disappointment it way empty: she did not like to drop the jar for fear of killing somebody, so managed to put it into one of the cupboards as she fell past it.
no jury
or judge,
would be
wasting
our
breath.'
'I will be
judge, I will
be jury,'
Said
cunning
old Fury:
'I will
try the
whole
cause,
and
condemn
you
to
death.
'You are not attending!' said the Mouse to Alice severely. 'What are you thinking of?'
'I beg your pardon,' said Alice very humbly: 'you had got to the fifth bend, I think?'
'I had NOT!' cried the Mouse, sharply and very angrily.
'A knot!' said Alice, always ready to make herself useful, and looking anxiously about her. 'Oh, do let me help to undo it!'
'I shall do nothing of the sort,' said the Mouse, getting up and walking away. 'You insult me by talking such nonsense!'
'I did not mean it!' pleaded poor Alice. 'But you are so easily offended, you know!'
The Mouse only growled in reply.
'Please come back and finish your story!' Alice called after it; and the others all joined in chorus, 'Yes, please do!' but the Mouse only shook its head impatiently, and walked a little quicker.
'What a pity it would not stay!' sighed the Lory, as soon as it was quite out of sight; and an old Crab took the opportunity of saying to her daughter 'Ah, my dear! Let this be a lesson to you never to lose YOUR temper!' 'Hold your tongue, Ma!' said the young Crab, a little snappishly. 'you are enough to try the patience of an oyster!'
'I wish I had our Dinah here, I know I do!' said Alice aloud, addressing nobody in particular. 'She would soon fetch it back!'
'And who is Dinah, if I might venture to ask the question?' said the Lory.
Alice replied eagerly, for she was always ready to talk about her pet: 'Dinah is our cat. And she is such a capital one for catching mice you could not think! And oh, I wish you could see her after the birds! Why, she will eat a little bird as soon as look at it!'
This speech caused a remarkable sensation among the party. Some of the birds hurried off at once: one the old Magpie began wrapping itself up very carefully, remarking, 'I really must be getting home; the night-air doesn't suit my throat!' and a Canary called out in a trembling voice to its children, 'Come away, my dears! it is high time you were all in bed!' On various pretexts they all moved off, and Alice was soon left alone.
'I wish I had not mentioned Dinah!' she said to herself in a melancholy tone. 'Nobody seems to like her, down here, and I am sure she is the best cat in the world! Oh, my dear Dinah! I wonder if I shall ever see you any more!' And here poor Alice began to cry again, for she felt very lonely and low-spirited. In a little while, however, she again heard a little pattering of footsteps in the distance, and she looked up eagerly, half hoping that the Mouse had changed his mind, and was coming back to finish his story.
"""

# %% [markdown]
# Подсчет числа строк в исходном тексте

# %%
lines = text.splitlines() # найдем количесство строк исхдного текста
print('Количество строк в исходном тексте: {}'.format(len(lines)))
# Out:
# Количество строк в исходном тексте: 157

# %% [markdown]
# Подсчет числа слов и средей длинны слова

# %%
text_word = text.replace("CHAPTER I", "").replace("CHAPTER II", "").replace("CHAPTER III", "") # удалим обозначение глав
text_word = text_word.lower()# Приводим текст к нижнему регистру
text_word = text_word.replace("\n", " ") # Заменяем символы переноса строки на пробелы
# удаляем знаки препинания
text_word = text_word.replace("!", "")
text_word = text_word.replace("'", "")
text_word = text_word.replace("(", "")
text_word = text_word.replace(")", "")
text_word = text_word.replace(",", "")
text_word = text_word.replace(";", "")
text_word = text_word.replace("-", "")
text_word = text_word.replace(":", "")
text_word = text_word.replace("?", "")
text_word = text_word.replace(".", "")

word_list = text_word.split() #разделяем по пробелам

word_set = set(word_list)# Превращаем список в множество, удаляя дублирующиеся слова

# находим среднюю длинну слова из общего числа слов
avg_word_length = sum(len(word) for word in word_list) / len(word_list)
# находим среднюю длинну слова из уникальных слов
avg_word_length_unic = sum(len(word) for word in word_set) / len(word_set)

print('Общее количество слов: {}'.format(len(word_list)))
print('Общее количество уникальных слов: {}'.format(len(word_set)))
print('Средняя длинна слова из всех слов: {}'.format(round((avg_word_length),2)))
print('Средняя длинна слова из уникальных слов: {}'.format(round((avg_word_length_unic),2)))
# Out:
# Общее количество слов: 6061
# Общее количество уникальных слов: 1156
# Средняя длинна слова из всех слов: 3.94
# Средняя длинна слова из уникальных слов: 5.79

# %%
# from collections import Counter

word_to_find = input()


# word_counts = Counter(word_list)
word_counts = {} 
# Создаём цикл по словам в списке word_list
# word — текущее слово из списка word_list
for word in word_list: 
    # Проверяем условие, что слова ещё нет среди ключей словаря.
    if word not in word_counts:
        # Если условие выполняется, заносим слово в словарь со значением 1.
        word_counts[word] = 1
    else: 
        # В противном случае увеличиваем частоту слова
        word_counts[word] += 1


count = word_counts.get(word_to_find, 0) # .get() вернет 0, если слова нет
print(f"Слово '{word_to_find}' встречается {count} раз.") # Вывод: 3
# Out:
# Слово 'was' встречается 107 раз.

# %%
count_dict = {} 
# Создаём цикл по словам в списке word_list
# word — текущее слово из списка word_list
for word in word_list: 
    # Проверяем условие, что слова ещё нет среди ключей словаря.
    if word not in count_dict:
        # Если условие выполняется, заносим слово в словарь со значением 1.
        count_dict[word] = 1
    else: 
        # В противном случае увеличиваем частоту слова
        count_dict[word] += 1
# Выводим результирующий словарь
words=sorted(count_dict.items(),key=lambda item: item[1], reverse=True )
print (words)
# Выводим как текстовый список
print("--- Текстовое облако слов ---")
for word, count_dict in words:
    print(f"{word}: {count_dict}") # Форматированный вывод: "слово: частота"
print("----------------------------")
# Out:
# [('the', 282), ('and', 209), ('to', 189), ('she', 172), ('a', 146), ('i', 145), ('it', 143), ('was', 107), ('of', 102), ('in', 86), ('you', 77), ('alice', 76), ('that', 66), ('her', 65), ('is', 63), ('not', 63), ('said', 54), ('as', 53), ('had', 47), ('but', 45), ('for', 45), ('all', 44), ('be', 41), ('down', 40), ('on', 40), ('with', 39), ('very', 38), ('will', 38), ('this', 37), ('little', 37), ('mouse', 37), ('so', 34), ('at', 31), ('if', 31), ('do', 29), ('out', 27), ('how', 26), ('they', 26), ('up', 25), ('herself', 25), ('what', 24), ('could', 24), ('one', 24), ('would', 23), ('like', 23), ('about', 23), ('me', 23), ('no', 22), ('thought', 22), ('when', 22), ('way', 22), ('know', 21), ('there', 20), ('see', 20), ('again', 20), ('am', 20), ('or', 19), ('think', 18), ('have', 18), ('went', 18), ('dear', 17), ('were', 17), ('oh', 16), ('must', 16), ('did', 15), ('time', 15), ('such', 15), ('them', 15), ('by', 14), ('into', 14), ('quite', 14), ('then', 14), ('here', 14), ('soon', 1
# ...

# %% [markdown]
# Определим 10 самых частотных слов (исключая предлоги, союзы, местоимения и артикли)

# %%
# создаем список исключений (предлоги, союзы, местоимения, артикли)
stop_words = {"at", "in","on", "during", "for","since", "by", "untill","till", "before", "after","between", "ago", "within","in", "on", "at","under",
              "above", "over","below", "between", "among","behind", "in front of", "beside","next to", "across from", "through","around", "along", 
              "to","towards", "into", "out of","onto", "off", "up",  "down", "for", "from", "with", "of", 
              "and", "that","but", "or", "as","if", "when", "than","because", "while", "where","after", "so", "now","i", "you", "he","she",
              "it", "we","they","me", "him", "her", "it", "us", "them", "a", "an","the"}
word_list_sorted=[word for word in word_list if word not in stop_words]
#print(word_list_sorted)


count_dict = {} 
# Создаём цикл по словам в списке word_list
# word — текущее слово из списка word_list
for word in word_list_sorted: 
    # Проверяем условие, что слова ещё нет среди ключей словаря.
    if word not in count_dict:
        # Если условие выполняется, заносим слово в словарь со значением 1.
        count_dict[word] = 1
    else: 
        # В противном случае увеличиваем частоту слова
        count_dict[word] += 1
# Выводим результирующий словарь
sorted_words=sorted(count_dict.items(),key=lambda item: item[1], reverse=True )
#print('Десять самых частотных слов (исключая предлоги, союзы, местоимения и артикли): {}'.format(sorted_words[:10]))



# 5. Выводим как текстовый список
print("--- Десять самых частотных слов (исключая предлоги, союзы, местоимения и артикли): ---")
for word, count_dict in sorted_words:
    print(f"{word}: {count_dict}") # Форматированный вывод: "слово: частота"
print("----------------------------")
# Out:
# --- Десять самых частотных слов (исключая предлоги, союзы, местоимения и артикли): ---
# was: 107
# alice: 76
# is: 63
# not: 63
# said: 54
# had: 47
# all: 44
# be: 41
# very: 38
# will: 38
# this: 37
# little: 37
# mouse: 37
# do: 29
# out: 27
# how: 26
# herself: 25
# what: 24
# could: 24
# one: 24
# would: 23
# like: 23
# about: 23
# no: 22
# thought: 22
# way: 22
# know: 21
# there: 20
# see: 20
# again: 20
# am: 20
# think: 18
# have: 18
# went: 18
# dear: 17
# were: 17
# oh: 16
# must: 16
# did: 15
# time: 15
# such: 15
# quite: 14
# then: 14
# here: 14
# soon: 14
# my: 14
# go: 14
# get: 13
# say: 13
# shall: 13
# found: 13
# your: 13
# dodo: 13
# which: 12
# come: 12
# began: 12
# long: 12
# thing: 12
# much: 11
# feet: 11
# first: 11
# things: 11
# are: 11
# dinah: 11
# cats: 11
# round: 11
# poor: 11
# who: 11
# nothing: 10
# once: 10
# well: 10
# rabbit: 10
# its: 10
# never: 10
# wonder: 10
# let: 10
# ever: 10
# door: 10
# any: 10
# back: 10
# more: 10
# cried: 10
# ...

# %% [markdown]
# общее колличество предложений и средняя длинна предложения

# %%
text_sentences = text.replace("CHAPTER I", "").replace("CHAPTER II", "").replace("CHAPTER III", "")# удалим обозначение глав
# Заменяем символы переноса строки на пробелы, удаляем скобки и кавычки
text_sentences = text_sentences.replace("\n", " ")
#избавимся от кавычек и скобок чтобы преобразовать прямую речь в предложение. 
text_sentences = text_sentences.replace("'", "")
text_sentences = text_sentences.replace("(", "")
text_sentences = text_sentences.replace(")", "")
# заменяем ! и ? на . для последующей разбивке текста по этому признаку. 
text_sentences = text_sentences.replace('?', '.')
text_sentences = text_sentences.replace('!', '.')
# разделяем текст по .
text_sentences = text_sentences.split('.')

print('Общее количество предложений: {}'.format(len(text_sentences)))

# создадим функция для подсчета средней длинны предложения. 
def average_sentence_length_in_words(text_sentences):
    if not text_sentences:
        return 0
    total_words = 0
    for sent in text_sentences:
        total_words += len(word_list)
        return total_words / len(text_sentences)
print('Средняя длинна предложения: {}'.format(round(   (average_sentence_length_in_words(text_sentences)),2)))
# Out:
# Общее количество предложений: 317
# Средняя длинна предложения: 19.12

# %% [markdown]
# код для записи в файл result.txt

# %%
with open('result.txt', 'w', encoding='utf-8') as f:
    f.write(f"Количество строк в исходном файле: {(len(lines))}\n")
    f.write(f"Общее количество слов: {(len(word_list))}\n") 
    f.write(f"Общее количество уникальных слов: {(len(word_set))}\n")
    f.write(f"Средняя длинна слова из всех слов: {(round((avg_word_length),2))}\n")
    f.write(f"Средняя длинна слова из уникальных слов: {(round((avg_word_length_unic),2))}\n")
    f.write(f"Общее количество предложений: {(len(text_sentences))}\n")
    f.write(f"Средняя длинна предложения: {(round(   (average_sentence_length_in_words(text_sentences)),2))}\n")
    f.write(f"Слово '{word_to_find}' встречается {count} раз.\n")
    f.write(f" \n")
    f.write(f"--- Текстовое облако слов ---- \n")
    f.write(f"{words}\n")
    f.write(f" \n")
    f.write(f"--- Десять самых частотных слов (исключая предлоги, союзы, местоимения и артикли)---\n")
    f.write(f"{(sorted_words[:10])}\n")
    f.write(f" \n")

# %%
# from collections import Counter

word_to_find = input()


# word_counts = Counter(word_list)
word_counts = {} 
# Создаём цикл по словам в списке word_list
# word — текущее слово из списка word_list
for word in word_list: 
    # Проверяем условие, что слова ещё нет среди ключей словаря.
    if word not in word_counts:
        # Если условие выполняется, заносим слово в словарь со значением 1.
        word_counts[word] = 1
    else: 
        # В противном случае увеличиваем частоту слова
        word_counts[word] += 1


count = word_counts.get(word_to_find, 0) # .get() вернет 0, если слова нет
print(f"Слово '{word_to_find}' встречается {count} раз.") # Вывод: 3

# %%
from collections import Counter
import re

# # Исходный текст
# text = "Привет мир! Это пример текста. Здесь много разных слов, например, 'алфавит', 'арбуз', 'банан', 'белка', 'кот' и 'компьютер'."

# # 1. Очистка текста от знаков препинания и приведение к нижнему регистру
# # Используем регулярное выражение для удаления не-букв и пробелов
# cleaned_text = re.sub(r'[^\w\s]', '', text.lower())

# # 2. Разбиваем текст на слова
# words = cleaned_text.split()

# 3. Получаем список первых букв слов
# Проверяем, что слово не пустое (на случай, если были множественные пробелы)
first_letters = [word[0] for word in word_list if word]
print(first_letters)




# 4. Считаем количество слов, начинающихся с каждой буквы
letter_counts = Counter(first_letters)

# 5. Выводим результат
print(letter_counts)
print('Колличество слов начинающихся с определенной буквы в тексте: {}'.format((letter_counts)))



# Инициализируем пустой словарь
word_counts = {}
# Инициализируем количество глав
count_chapter = 0
# Создаем цикл по всем словам из списка слов
for word in text:
    # Проверяем, что текущее слово - обозначение новой главы
    if word == 'CHAPTER':
        # Если условие выполняется, то увеличиваем количество глав на 1
        count_chapter += 1
        # Переходим на новую итерацию цикла
        continue
    # Проверяем, что текущего слова еще нет в словаре слов
    if word not in word_counts:
        # Если условие выполняется, инициализируем новый ключ 1
        word_counts[word] = 1
    else:
        # В противном случае, увеличиваем количество слов на 1
        word_counts[word] += 1

# Выводим количество глав
print('Количество глав: {}'.format(count_chapter))
# Out:
# ['d', 't', 'r', 'a', 'w', 'b', 't', 'g', 'v', 't', 'o', 's', 'b', 'h', 's', 'o', 't', 'b', 'a', 'o', 'h', 'n', 't', 'd', 'o', 'o', 't', 's', 'h', 'p', 'i', 't', 'b', 'h', 's', 'w', 'r', 'b', 'i', 'h', 'n', 'p', 'o', 'c', 'i', 'i', 'a', 'w', 'i', 't', 'u', 'o', 'a', 'b', 't', 'a', 'w', 'p', 'o', 'c', 's', 's', 'w', 'c', 'i', 'h', 'o', 'm', 'a', 'w', 'a', 's', 'c', 'f', 't', 'h', 'd', 'm', 'h', 'f', 'v', 's', 'a', 's', 'w', 't', 'p', 'o', 'm', 'a', 'd', 'w', 'b', 'w', 't', 't', 'o', 'g', 'u', 'a', 'p', 't', 'd', 'w', 's', 'a', 'w', 'r', 'w', 'p', 'e', 'r', 'c', 'b', 'h', 't', 'w', 'n', 's', 'v', 'r', 'i', 't', 'n', 'd', 'a', 't', 'i', 's', 'v', 'm', 'o', 'o', 't', 'w', 't', 'h', 't', 'r', 's', 't', 'i', 'o', 'd', 'o', 'd', 'i', 's', 'b', 'l', 'w', 's', 't', 'i', 'o', 'a', 'i', 'o', 't', 'h', 't', 's', 'o', 't', 'h', 'w', 'a', 't', 'b', 'a', 't', 't', 'i', 'a', 's', 'q', 'n', 'b', 'w', 't', 'r', 'a', 't', 'a', 'w', 'o', 'o', 'i', 'w', 'a', 'l', 'a', 'i', 'a', 't', 'h', 'o', 'a', 's', 't
# ...

# %%
# Инициализируем пустой словарь
word_counts = {}
# Инициализируем количество глав
count_chapter = 0
# Создаем цикл по всем словам из списка слов
for word in text:
    # Проверяем, что текущее слово - обозначение новой главы
    if word == 'CHAPTER':
        # Если условие выполняется, то увеличиваем количество глав на 1
        count_chapter += 1
        # Переходим на новую итерацию цикла
        continue
    # Проверяем, что текущего слова еще нет в словаре слов
    if word not in word_counts:
        # Если условие выполняется, инициализируем новый ключ 1
        word_counts[word] = 1
    else:
        # В противном случае, увеличиваем количество слов на 1
        word_counts[word] += 1

# Выводим количество глав
print('Количество глав: {}'.format(count_chapter))

# Создаем цикл по ключам и их порядковым номерам полученного словаря
for i, key in enumerate(word_counts):
    # Выводим только первые 10 слов
    if i == 10:
        break
    print(key, word_counts[key])
# Out:
# Количество глав: 0
#
#  157
# C 22
# H 35
# A 133
# P 13
# T 52
# E 39
# R 28
#   5924
# I 172
