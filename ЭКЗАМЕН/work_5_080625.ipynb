# %% [markdown]
# Тренировочный вариант 5

# %% [markdown]
# Вопрос 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 3

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 4

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 7

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 8

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# вопрос 9

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 10

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# вопрос 11

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# вопрос 12

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### СЕКЦИЯ В

# %% [markdown]
# Вопрос 6

# %%
import pandas as pd

df = pd.read_csv('C:\скил\DST-156\IDE_NEW\ЭКЗАМЕН/train5_b.csv')
df
# Out:
#      Soil_Type  Sunlight_Hours  Temperature   Humidity
# 0            2        5.192294    31.719602  61.591861
# 1            3        4.033133    28.919484  52.422276
# 2            2        8.892769    23.179059  44.660539
# 3            2        8.241144    18.465886  46.433227
# 4            3        8.374043    18.128741  63.625923
# ..         ...             ...          ...        ...
# 188          3        5.652000    28.000000  70.200000
# 189          1        7.528000    30.500000  60.100000
# 190          2        4.934000    24.500000  61.700000
# 191          3        8.273000    27.900000  69.500000
# 192          1        6.732000    21.700000  56.900000
#
# [193 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Soil_Type       193 non-null    int64
#  1   Sunlight_Hours  193 non-null    float64
#  2   Temperature     193 non-null    float64
#  3   Humidity        193 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 6.2 KB

# %% [markdown]
# ![](attachment:image.png)

# %% [markdown]
# вопрос 13

# %%
df['Humidity'].plot(kind = 'box', vert = False) #vert = False, чтобы ящик был горизонтальный
# Out:
# <Axes: >

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 14

# %%
df.plot('Temperature', 'Humidity', kind = 'scatter')
# Out:
# <Axes: xlabel='Temperature', ylabel='Humidity'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# вопрос 15

# %%
df['Soil_Type'].mode()[0]
# Out:
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 16

# %%
df['Sunlight_Hours'].corr(df['Temperature']) #если поменять местами ответ не изменится
# Out:
# -0.10062817733107511

# %%
df['Temperature'].corr(df['Sunlight_Hours']) #если поменять местами ответ не изменится
# Out:
# -0.10062817733107511

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### СЕКЦИЯ C

# %%
import pandas as pd

df_5c = pd.read_csv('C:\скил\DST-156\IDE_NEW\ЭКЗАМЕН/train5_c.csv')
df_5c
# Out:
#                                                 Resort          Country  \
# 0                                Alpendorf (Ski amedé)          Austria
# 1    Soldeu-Pas de la Casa/​Grau Roig/​El Tarter/​C...          Andorra
# 2                                Oberau (Wildschönau)          Austria
# 3                                       Dachstein West          Austria
# 4                                          Rosa Khutor  Southern Russia
# ..                                                 ...              ...
# 371                          Montgenèvre (Via Lattea)           France
# 372                          Sauze d’Oulx (Via Lattea)            Italy
# 373             Gressoney - La-Trinite (Monterosa Ski)            Italy
# 374                          Champoluc (Monterosa Ski)            Italy
# 375                                         Zauchensee          Austria
#
#      HighestPoint  LowestPoint  DayPassPriceAdult  TotalSlope NightSki  \
# ...

# %%
df_5c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 376 entries, 0 to 375
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Resort             376 non-null    object
#  1   Country            376 non-null    object
#  2   HighestPoint       376 non-null    int64
#  3   LowestPoint        376 non-null    int64
#  4   DayPassPriceAdult  376 non-null    int64
#  5   TotalSlope         376 non-null    int64
#  6   NightSki           376 non-null    object
#  7   TotalLifts         376 non-null    int64
#  8   LiftCapacity       376 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 26.6+ KB

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Вопрос 17

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Для страны (Country), где больше всего горнолыжных курортов, найдите название курорта (Resort), с наименьшей высотой пика по признаку HighestPoint.
#
# Пример ответа: Alpendorf (Ski amedé)

# %%
df_5c[(df_5c['Country'] == 'Austria')].sort_values('HighestPoint')
# Out:
#                                         Resort  Country  HighestPoint  \
# 206                                  Kirchdorf  Austria           780
# 228                          Kellerjoch-Schwaz  Austria           857
# 183                   Tauplitz-Bad Mitterndorf  Austria           896
# 152                                  Gerlitzen  Austria          1000
# 2                        Oberau (Wildschönau)  Austria          1130
# ..                                         ...      ...           ...
# 269                        Obergurgl-Hochgurgl  Austria          3082
# 272  Kaunertal Glacier (Kaunertaler Gletscher)  Austria          3108
# 367                             Stubai Glacier  Austria          3212
# 82                           Hintertux Glacier  Austria          3250
# 366                                     Sölden  Austria          3340
#
#      LowestPoint  DayPassPriceAdult  TotalSlope NightSki  TotalLifts  \
# ...

# %% [markdown]
# Вопрос 18

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_5c_18=df_5c[(df_5c['NightSki'] == 'Yes')]

# %%
df_5c_18['LiftCapacity'].quantile(0.75)-df_5c_18['LiftCapacity'].quantile(0.25)
# Out:
# 45356.0

# %% [markdown]
# вопрос 19

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_5c_19=df_5c.groupby('Country')[['HighestPoint', 'LowestPoint']].mean()
df_5c_19
# Out:
#                         HighestPoint  LowestPoint
# Country
# Andorra                  2419.000000  1660.000000
# Austria                  2089.247191  1021.977528
# Bosnia and Herzegovina   1889.000000   920.000000
# Bulgaria                 2334.000000  1159.000000
# Czech Republic           1218.500000   778.000000
# Denmark                    66.125000    35.625000
# Finland                   580.333333   232.333333
# France                   2414.626506  1249.674699
# Germany                  1354.208333   823.791667
# Greece                   2300.000000  1600.000000
# Italy                    2322.431818  1208.613636
# Liechtenstein            2000.000000  1600.000000
# Lithuania                 163.000000    97.000000
# Netherlands               210.000000   150.000000
# Norway                   1172.500000   553.400000
# Poland                   1083.500000   602.000000
# Romania                  1339.500000   927.500000
# Serbia                   2017.000000  1057.000000
# ...

# %%
df_5c_19_1=df_5c_19['HighestPoint']-df_5c_19['LowestPoint']
df_5c_19_1.sort_values()
# Out:
# Country
# Denmark                     30.500000
# Netherlands                 60.000000
# Lithuania                   66.000000
# Finland                    348.000000
# Liechtenstein              400.000000
# Romania                    412.000000
# Sweden                     414.333333
# United Kingdom             415.500000
# Czech Republic             440.500000
# Poland                     481.500000
# Ukraine                    482.000000
# Germany                    530.416667
# Siberia (Russia)           600.000000
# Norway                     619.100000
# Greece                     700.000000
# Slovenia                   750.000000
# Andorra                    759.000000
# Slovakia                   790.000000
# Spain                      917.625000
# Serbia                     960.000000
# Bosnia and Herzegovina     969.000000
# Southern Russia            973.750000
# Austria                   1067.269663
# Italy                     1113.818182
# ...

# %% [markdown]
# вопрос 20

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def clss(x):
  if x == 'Siberia (Russia)':
    return 1
  if x == 'Southern Russia':
    return 1 
  else:
    return 0

# %%
df_5c['coded'] = df_5c['Country'].apply(clss)
df_5c['coded'].sum()
# Out:
# 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# вопрос 21

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
avg = df_5c['TotalLifts'].mean()
std = df_5c['TotalLifts'].std()
low2 = avg-2*std #можно посчитать отклонение и на одно, и на два, и на три
up2 = avg+2*std
low2, up2
# Out:
# (-35.12046717267368, 89.03536078969495)

# %%
df_5c[(df_5c['TotalLifts']<low2) | (df_5c['TotalLifts']>up2)].shape[0]
# Out:
# 17

# %% [markdown]
# вопрос 22

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_5c.corr(numeric_only = True)
# Out:
#                    HighestPoint  LowestPoint  DayPassPriceAdult  TotalSlope  \
# HighestPoint           1.000000     0.726553           0.533034    0.473086
# LowestPoint            0.726553     1.000000           0.202030    0.120881
# DayPassPriceAdult      0.533034     0.202030           1.000000    0.509066
# TotalSlope             0.473086     0.120881           0.509066    1.000000
# TotalLifts             0.382296     0.052858           0.462889    0.940646
# LiftCapacity           0.389346     0.054446           0.462764    0.936038
# coded                 -0.075772    -0.112155          -0.238369   -0.059132
#
#                    TotalLifts  LiftCapacity     coded
# HighestPoint         0.382296      0.389346 -0.075772
# LowestPoint          0.052858      0.054446 -0.112155
# DayPassPriceAdult    0.462889      0.462764 -0.238369
# TotalSlope           0.940646      0.936038 -0.059132
# TotalLifts           1.000000      0.983835 -0.048528
# ...

# %% [markdown]
# Вопрос 23

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import statsmodels.api as sm
Y = df_5c['DayPassPriceAdult']
X = sm.add_constant(df_5c['TotalSlope'])
model = sm.OLS(Y, X).fit()
round(model.params, 2)[1]
# Out:
# C:\Users\molde\AppData\Local\Temp\ipykernel_21556\1140357386.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   round(model.params, 2)[1]
# 0.06

# %% [markdown]
# Вопрос 24

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Y_pr = model.predict(X)
MAE = sum(abs(Y-Y_pr))/len(Y)
round(MAE,2)
# Out:
# 8.24
